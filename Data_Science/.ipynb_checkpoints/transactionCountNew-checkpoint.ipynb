# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from functools import reduce
from pylab import figure, axes, pie, title, savefig
# %matplotlib inline

# %%
df = pd.read_csv("/Users/hamin/bithumb_bot_data/include/2018/2018-01-btc-krw.csv")

# %%
df.dtypes # identifying column type
# Out:
# timestamp     object
# quantity     float64
# price          int64
# fee          float64
# amount         int64
# side           int64
# dtype: object

# %%
## converting timestamp column type 'object' to 'datetime'
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d %H:%M:%S', errors='raise')
df.dtypes
# Out:
# timestamp    datetime64[ns]
# quantity            float64
# price                 int64
# fee                 float64
# amount                int64
# side                  int64
# dtype: object

# %%
## converting timestamp to detailed date column
df['timestamp_year_month_day'] = df['timestamp'].dt.date         # YYYY-MM-DD(문자)
df['timestamp_year'] = df['timestamp'].dt.year         # 연(4자리숫자)
df['timestamp_month'] = df['timestamp'].dt.month        # 월(숫자)
df['timestamp_month_name'] = df['timestamp'].dt.month_name() # 월(문자)

df['timestamp_day'] = df['timestamp'].dt.day          # 일(숫자)
df['timestamp_time'] = df['timestamp'].dt.time         # HH:MM:SS(문자)
df['timestamp_hour'] = df['timestamp'].dt.hour         # 시(숫자)
df['timestamp_minute'] = df['timestamp'].dt.minute       # 분(숫자)
df['timestamp_second'] = df['timestamp'].dt.second       # 초(숫자)

# %%
## creating 'hour - amount' connection
group_hour_amount = df['amount'].groupby(df['timestamp_hour'])

# %%
## 시간별 transaction 수
group_hour_amount.size()
# Out:
# timestamp_hour
# 0     27
# 1     31
# 2     19
# 3     27
# 4     19
# 5     25
# 6     22
# 7     33
# 8     35
# 9     37
# 10    16
# 11    27
# 12    32
# 13    71
# 14    43
# 15    40
# 16    30
# 17    56
# 18    52
# 19    30
# 20    18
# 21    39
# 22    33
# 23    61
# Name: amount, dtype: int64

# %%
## 시간별 총 sell - buy
group_hour_amount.sum()
# Out:
# timestamp_hour
# 0      -17143
# 1       42764
# 2      -42964
# 3       16843
# 4       14385
# 5      -44088
# 6       42053
# 7      -14038
# 8        9339
# 9      -39690
# 10         81
# 11      29442
# 12    1022708
# 13    3370703
# 14     -11828
# 15      26610
# 16     -35201
# 17     -23159
# 18      51460
# 19     -26883
# 20        467
# 21      14165
# 22   -1468464
# 23     -33010
# Name: amount, dtype: int64

# %%
## creating 'hourly - buy amount' connection
df2 = df.copy()
df2 =df2[df2['amount'] > 0]
group_hour_amount_positive = df2['amount'].groupby(df2['timestamp_hour'])

# %%
# 시간별 sell transaction 수 (positive)
group_hour_amount_positive.size()
# Out:
# timestamp_hour
# 0     13
# 1     17
# 2      8
# 3     14
# 4     10
# 5     11
# 6     12
# 7     16
# 8     18
# 9     17
# 10     8
# 11    15
# 12    15
# 13    37
# 14    21
# 15    21
# 16    14
# 17    27
# 18    27
# 19    14
# 20     9
# 21    20
# 22    16
# 23    29
# Name: amount, dtype: int64

# %%
# 시간별 sell 총합
group_hour_amount_positive.sum()
# Out:
# timestamp_hour
# 0      180475
# 1      243126
# 2      107227
# 3      201779
# 4      146223
# 5      153733
# 6      183869
# 7      229702
# 8      256367
# 9      253951
# 10     106303
# 11     200395
# 12    1274565
# 13    3870996
# 14     307147
# 15     311094
# 16     194337
# 17     369788
# 18     408519
# 19     208090
# 20     129441
# 21     273726
# 22     232297
# 23     416748
# Name: amount, dtype: int64

# %%
## creating 'hour - buy amount' connection
df3 = df.copy()
df3 = df3[df3['amount'] < 0]
group_hour_amount_negative = df3['amount'].groupby(df3['timestamp_hour'])

# %%
# 시간별 buy transaction 수
group_hour_amount_negative.size()
# Out:
# timestamp_hour
# 0     14
# 1     14
# 2     11
# 3     13
# 4      9
# 5     14
# 6     10
# 7     17
# 8     17
# 9     20
# 10     8
# 11    12
# 12    17
# 13    34
# 14    22
# 15    19
# 16    16
# 17    29
# 18    25
# 19    16
# 20     9
# 21    19
# 22    17
# 23    32
# Name: amount, dtype: int64

# %%
# 시간별 buy 총합
group_hour_amount_negative.sum()
# Out:
# timestamp_hour
# 0     -197618
# 1     -200362
# 2     -150191
# 3     -184936
# 4     -131838
# 5     -197821
# 6     -141816
# 7     -243740
# 8     -247028
# 9     -293641
# 10    -106222
# 11    -170953
# 12    -251857
# 13    -500293
# 14    -318975
# 15    -284484
# 16    -229538
# 17    -392947
# 18    -357059
# 19    -234973
# 20    -128974
# 21    -259561
# 22   -1700761
# 23    -449758
# Name: amount, dtype: int64

# %%
# 시간별 절대값 총합
# negative는 buy
absolute_negative_sum = group_hour_amount_negative.sum()
absolute_negative_sum = absolute_negative_sum * (-1)
# total 은 sell - buy
absolute_total_amount = absolute_negative_sum+group_hour_amount_positive.sum()
absolute_total_amount
# Out:
# timestamp_hour
# 0      378093
# 1      443488
# 2      257418
# 3      386715
# 4      278061
# 5      351554
# 6      325685
# 7      473442
# 8      503395
# 9      547592
# 10     212525
# 11     371348
# 12    1526422
# 13    4371289
# 14     626122
# 15     595578
# 16     423875
# 17     762735
# 18     765578
# 19     443063
# 20     258415
# 21     533287
# 22    1933058
# 23     866506
# Name: amount, dtype: int64

# %%
## 시간별 계산 table 생성
dfs = [group_hour_amount.size(), group_hour_amount.sum(), group_hour_amount_positive.size(), group_hour_amount_positive.sum(), group_hour_amount_negative.size(), group_hour_amount_negative.sum(), absolute_total_amount, absolute_negative_sum]
day_df_final = reduce(lambda left,right: pd.merge(left,right,on='timestamp_hour'), dfs)
day_df_final.columns = [ "Hourly transaction", "Hourly sell-buy", "Hourly sell transaction", "Hourly sell", "Hourly buy transaction", "Hourly buy", "Hourly total sell", "Hourly absolute total buy"]
day_df_final
# Out:
#                 Hourly transaction  Hourly sell-buy  Hourly sell transaction  \
# timestamp_hour
# 0                               27           -17143                       13
# 1                               31            42764                       17
# 2                               19           -42964                        8
# 3                               27            16843                       14
# 4                               19            14385                       10
# 5                               25           -44088                       11
# 6                               22            42053                       12
# 7                               33           -14038                       16
# 8                               35             9339                       18
# 9                               37           -39690                       17
# 10                              16               81                        8
# 11                              27            29442                       15
# 12                              32          1022708                       15
# 13                              71          3370703                       37
# 14                              43           -11828                       21
# 15                              40            26610                       21
# 16                              30           -35201                       14
# 17                              56           -23159                       27
# 18                              52            51460                       27
# 19                              30           -26883                       14
# 20                              18              467                        9
# 21                              39            14165                       20
# 22                              33         -1468464                       16
# 23                              61           -33010                       29
#
#                 Hourly sell  Hourly buy transaction  Hourly buy  \
# timestamp_hour
# 0                    180475                      14     -197618
# 1                    243126                      14     -200362
# 2                    107227                      11     -150191
# 3                    201779                      13     -184936
# 4                    146223                       9     -131838
# 5                    153733                      14     -197821
# 6                    183869                      10     -141816
# 7                    229702                      17     -243740
# 8                    256367                      17     -247028
# 9                    253951                      20     -293641
# 10                   106303                       8     -106222
# 11                   200395                      12     -170953
# 12                  1274565                      17     -251857
# 13                  3870996                      34     -500293
# 14                   307147                      22     -318975
# 15                   311094                      19     -284484
# 16                   194337                      16     -229538
# 17                   369788                      29     -392947
# 18                   408519                      25     -357059
# 19                   208090                      16     -234973
# 20                   129441                       9     -128974
# 21                   273726                      19     -259561
# 22                   232297                      17    -1700761
# 23                   416748                      32     -449758
#
#                 Hourly total sell  Hourly absolute total buy
# timestamp_hour
# 0                          378093                     197618
# 1                          443488                     200362
# 2                          257418                     150191
# 3                          386715                     184936
# 4                          278061                     131838
# 5                          351554                     197821
# 6                          325685                     141816
# 7                          473442                     243740
# 8                          503395                     247028
# 9                          547592                     293641
# 10                         212525                     106222
# 11                         371348                     170953
# 12                        1526422                     251857
# 13                        4371289                     500293
# 14                         626122                     318975
# 15                         595578                     284484
# 16                         423875                     229538
# 17                         762735                     392947
# 18                         765578                     357059
# 19                         443063                     234973
# 20                         258415                     128974
# 21                         533287                     259561
# 22                        1933058                    1700761
# 23                         866506                     449758

# %%
day_df_final.to_csv("/Users/hamin/ITE3035_Python/Data_Science/table/hour_result_table_2018_01.csv", header=True, index=True, encoding = 'utf-8')

# %%
day_df_final[['Hourly transaction', 'Hourly sell transaction', 'Hourly buy transaction']].plot(title='Hourly transaction count', marker='o')
plt.savefig('/Users/hamin/ITE3035_Python/Data_Science/graph/Hourly transaction count_2018_01.png', dpi=300)

# %%
hourTransGraph = day_df_final[['Hourly sell transaction', 'Hourly buy transaction']].plot.bar(title='Hourly transaction count', stacked=True)
hourTransGraph.set_xlabel('Hour')
hourTransGraph.set_ylabel('Count')
plt.savefig('/Users/hamin/ITE3035_Python/Data_Science/graph/Hourly transaction count(Stacked))2018_01.png', dpi=300)

# %%
hourTransBarGraph = day_df_final[['Hourly sell transaction', 'Hourly buy transaction']].plot.bar(title='Hourly transaction count(Bar)')
hourTransBarGraph.set_xlabel('Hour')
hourTransBarGraph.set_ylabel('Count')
plt.savefig('/Users/hamin/ITE3035_Python/Data_Science/graph/Hourly transaction count(Bar)_2018_01.png', dpi=300)

# %%
# Minute
## creating 'minute - amount' connection
group_minute_amount = df['amount'].groupby(df['timestamp_minute'])

# %%
# Date
# Creating 'date - amount' connection
group_date_amount = df['amount'].groupby(df['timestamp_day'])

# %%
# 분 당 transaction 수
group_minute_amount.size()
# Out:
# timestamp_minute
# 0     12
# 1     15
# 2      5
# 3     17
# 4     11
# 5     15
# 6     16
# 7     17
# 8     12
# 9     15
# 10    18
# 11    10
# 12    19
# 13    18
# 14    11
# 15    18
# 16    21
# 17    14
# 18    12
# 19    11
# 20    14
# 21    18
# 22    10
# 23    19
# 24    19
# 25    10
# 26    15
# 27    12
# 28    10
# 29    11
# 30    14
# 31    10
# 32    15
# 33    10
# 34    13
# 35    10
# 36    12
# 37    11
# 38    14
# 39    14
# 40    16
# 41    10
# 42    16
# 43    12
# 44    14
# 45    11
# 46    16
# 47    19
# 48    13
# 49    14
# 50    15
# 51    17
# 52     9
# 53    14
# 54    11
# 55    11
# 56    15
# 57    16
# 58    10
# 59    16
# Name: amount, dtype: int64

# %%
# date 당 transaction 수
group_date_amount.size()
# Out:
# timestamp_day
# 3       1
# 10      1
# 11      1
# 18      1
# 19     40
# 20    153
# 21    154
# 22     69
# 23     96
# 24     86
# 25    217
# 31      4
# Name: amount, dtype: int64

# %%
# minute 별 sell - buy 금액
group_minute_amount.sum()
# Out:
# timestamp_minute
# 0      -56255
# 1      -75377
# 2       43805
# 3      -18577
# 4       89048
# 5       67830
# 6       46844
# 7      -14376
# 8      -48688
# 9      -69029
# 10       1580
# 11      76519
# 12     -24074
# 13      33322
# 14      38111
# 15     -22753
# 16     -10057
# 17        238
# 18      -8785
# 19     -51893
# 20   -1392263
# 21      13276
# 22      12717
# 23    1091660
# 24     -26097
# 25     -31848
# 26      -8369
# 27      24079
# 28      -3003
# 29     -34700
# 30     -53498
# 31      21926
# 32      28289
# 33      29348
# 34     -23640
# 35        658
# 36      25832
# 37     -11387
# 38      40563
# 39      11495
# 40      -6380
# 41     -87775
# 42      22905
# 43      -5119
# 44    3264557
# 45      40831
# 46      53279
# 47     102159
# 48     -70635
# 49     -21198
# 50      41166
# 51     -17803
# 52     -10248
# 53     -27304
# 54     -91966
# 55     -70081
# 56      51101
# 57      -1376
# 58      43296
# 59     -37328
# Name: amount, dtype: int64

# %%
# date 별 sell - buy 금액
group_hour_amount.sum()
# Out:
# timestamp_hour
# 0      -17143
# 1       42764
# 2      -42964
# 3       16843
# 4       14385
# 5      -44088
# 6       42053
# 7      -14038
# 8        9339
# 9      -39690
# 10         81
# 11      29442
# 12    1022708
# 13    3370703
# 14     -11828
# 15      26610
# 16     -35201
# 17     -23159
# 18      51460
# 19     -26883
# 20        467
# 21      14165
# 22   -1468464
# 23     -33010
# Name: amount, dtype: int64

# %%
# creating 'minute' - buy amount' connection
df2 = df.copy()
df2 =df2[df2['amount'] > 0]
group_minute_amount_positive = df2['amount'].groupby(df2['timestamp_minute'])

# %%
# creating 'date' - buy amount' connection
df2 = df.copy()
df2 =df2[df2['amount'] > 0]
group_date_amount_positive = df2['amount'].groupby(df2['timestamp_day'])

# %%
# minute 별 sell transaction 수 (positive)
group_minute_amount_positive.size()
# Out:
# timestamp_minute
# 0      4
# 1      5
# 2      4
# 3      8
# 4      8
# 5     10
# 6     10
# 7      8
# 8      5
# 9      5
# 10     9
# 11     7
# 12     9
# 13    10
# 14     7
# 15     8
# 16    10
# 17     7
# 18     6
# 19     4
# 20     9
# 21     9
# 22     6
# 23    11
# 24     9
# 25     4
# 26     7
# 27     7
# 28     5
# 29     4
# 30     5
# 31     6
# 32     8
# 33     6
# 34     5
# 35     5
# 36     7
# 37     5
# 38     8
# 39     7
# 40     8
# 41     2
# 42     9
# 43     6
# 44     5
# 45     7
# 46    10
# 47    12
# 48     4
# 49     7
# 50     9
# 51     8
# 52     4
# 53     6
# 54     2
# 55     3
# 56     9
# 57     8
# 58     6
# 59     7
# Name: amount, dtype: int64

# %%
# date 별 sell transaction 수 (positive)
group_date_amount_positive.size()
# Out:
# timestamp_day
# 3       1
# 19     21
# 20     76
# 21     76
# 22     34
# 23     48
# 24     42
# 25    109
# 31      2
# Name: amount, dtype: int64

# %%
# minute 별 sell transaction 수 (positive)
group_minute_amount_positive.size()
# Out:
# timestamp_minute
# 0      4
# 1      5
# 2      4
# 3      8
# 4      8
# 5     10
# 6     10
# 7      8
# 8      5
# 9      5
# 10     9
# 11     7
# 12     9
# 13    10
# 14     7
# 15     8
# 16    10
# 17     7
# 18     6
# 19     4
# 20     9
# 21     9
# 22     6
# 23    11
# 24     9
# 25     4
# 26     7
# 27     7
# 28     5
# 29     4
# 30     5
# 31     6
# 32     8
# 33     6
# 34     5
# 35     5
# 36     7
# 37     5
# 38     8
# 39     7
# 40     8
# 41     2
# 42     9
# 43     6
# 44     5
# 45     7
# 46    10
# 47    12
# 48     4
# 49     7
# 50     9
# 51     8
# 52     4
# 53     6
# 54     2
# 55     3
# 56     9
# 57     8
# 58     6
# 59     7
# Name: amount, dtype: int64

# %%
# date 별 sell transaction 수 (positive)
group_date_amount_positive.size()
# Out:
# timestamp_day
# 3       1
# 19     21
# 20     76
# 21     76
# 22     34
# 23     48
# 24     42
# 25    109
# 31      2
# Name: amount, dtype: int64

# %%
# creating 'minute - buy amount' connection
df3 = df.copy()
df3 = df3[df3['amount'] < 0]
group_minute_amount_negative = df3['amount'].groupby(df3['timestamp_minute'])

# %%
## creating 'date - buy amount' connection
df3 = df.copy()
df3 = df3[df3['amount'] < 0]
group_date_amount_negative = df3['amount'].groupby(df3['timestamp_day'])

# %%
# minute 별 buy transaction 수
group_minute_amount_negative.size()
# Out:
# timestamp_minute
# 0      8
# 1     10
# 2      1
# 3      9
# 4      3
# 5      5
# 6      6
# 7      9
# 8      7
# 9     10
# 10     9
# 11     3
# 12    10
# 13     8
# 14     4
# 15    10
# 16    11
# 17     7
# 18     6
# 19     7
# 20     5
# 21     9
# 22     4
# 23     8
# 24    10
# 25     6
# 26     8
# 27     5
# 28     5
# 29     7
# 30     9
# 31     4
# 32     7
# 33     4
# 34     8
# 35     5
# 36     5
# 37     6
# 38     6
# 39     7
# 40     8
# 41     8
# 42     7
# 43     6
# 44     9
# 45     4
# 46     6
# 47     7
# 48     9
# 49     7
# 50     6
# 51     9
# 52     5
# 53     8
# 54     9
# 55     8
# 56     6
# 57     8
# 58     4
# 59     9
# Name: amount, dtype: int64

# %%
# date 별 buy transaction 수
group_date_amount_negative.size()
# Out:
# timestamp_day
# 10      1
# 11      1
# 18      1
# 19     19
# 20     77
# 21     78
# 22     35
# 23     48
# 24     44
# 25    108
# 31      2
# Name: amount, dtype: int64

# %%
# minute 별 buy 총합
group_minute_amount_negative.sum()
# Out:
# timestamp_minute
# 0     -114830
# 1     -141237
# 2      -13302
# 3     -130382
# 4      -40402
# 5      -75565
# 6      -90600
# 7     -125031
# 8     -105000
# 9     -144397
# 10    -129273
# 11     -42949
# 12    -148049
# 13    -111939
# 14     -58900
# 15    -145951
# 16    -156836
# 17     -99319
# 18     -92471
# 19     -99753
# 20   -1527762
# 21    -125608
# 22     -63778
# 23    -108335
# 24    -151015
# 25     -85687
# 26    -111715
# 27     -76484
# 28     -72345
# 29     -96912
# 30    -129306
# 31     -62831
# 32    -101329
# 33     -52900
# 34     -99482
# 35     -71062
# 36     -69869
# 37     -81662
# 38     -85543
# 39     -99886
# 40    -118153
# 41    -116599
# 42    -104580
# 43     -86147
# 44    -124274
# 45     -57634
# 46     -93728
# 47     -86475
# 48    -129931
# 49    -108585
# 50     -85492
# 51    -130496
# 52     -70166
# 53    -112268
# 54    -125085
# 55    -113307
# 56     -80744
# 57    -118298
# 58     -44016
# 59    -129671
# Name: amount, dtype: int64

# %%
# daye 별 buy 총합
group_date_amount_negative.sum()
# Out:
# timestamp_day
# 10   -1468934
# 11     -19563
# 18     -14572
# 19    -281984
# 20   -1238765
# 21   -1203446
# 22    -495598
# 23    -632173
# 24    -566980
# 25   -1431069
# 31     -22262
# Name: amount, dtype: int64

# %%
# minute 별 절대값 총합
# negative는 buy
absolute_minute_negative_sum = group_minute_amount_negative.sum()
absolute_minute_negative_sum = absolute_minute_negative_sum * (-1)
# total 은 sell - buy
absolute_minute_total_amount = absolute_minute_negative_sum+group_minute_amount_positive.sum()
absolute_minute_total_amount
# Out:
# timestamp_minute
# 0      173405
# 1      207097
# 2       70409
# 3      242187
# 4      169852
# 5      218960
# 6      228044
# 7      235686
# 8      161312
# 9      219765
# 10     260126
# 11     162417
# 12     272024
# 13     257200
# 14     155911
# 15     269149
# 16     303615
# 17     198876
# 18     176157
# 19     147613
# 20    1663261
# 21     264492
# 22     140273
# 23    1308330
# 24     275933
# 25     139526
# 26     215061
# 27     177047
# 28     141687
# 29     159124
# 30     205114
# 31     147588
# 32     230947
# 33     135148
# 34     175324
# 35     142782
# 36     165570
# 37     151937
# 38     211649
# 39     211267
# 40     229926
# 41     145423
# 42     232065
# 43     167175
# 44    3513105
# 45     156099
# 46     240735
# 47     275109
# 48     189227
# 49     195972
# 50     212150
# 51     243189
# 52     130084
# 53     197232
# 54     158204
# 55     156533
# 56     212589
# 57     235220
# 58     131328
# 59     222014
# Name: amount, dtype: int64

# %%
# date 별 절대값 총합
# negative는 buy
absolute_date_negative_sum = group_date_amount_negative.sum()
absolute_date_negative_sum = absolute_date_negative_sum * (-1)
# total 은 sell - buy
absolute_date_total_amount = absolute_date_negative_sum+group_date_amount_positive.sum()
absolute_date_total_amount
# Out:
# timestamp_day
# 3           NaN
# 10          NaN
# 11          NaN
# 18          NaN
# 19    1616316.0
# 20    2477956.0
# 21    2405151.0
# 22     976274.0
# 23    1265245.0
# 24    1132280.0
# 25    2873385.0
# 31      44438.0
# Name: amount, dtype: float64

# %%
# minute 별 계산 table 생성
dfs = [group_minute_amount.size(), group_minute_amount.sum(), group_minute_amount_positive.size(), group_minute_amount_positive.sum(), group_minute_amount_negative.size(), group_minute_amount_negative.sum(), absolute_minute_total_amount, absolute_minute_negative_sum]
day_df_minute_final = reduce(lambda left,right: pd.merge(left,right,on='timestamp_minute'), dfs)
day_df_minute_final.columns = [ "Minute transaction", "Minute sell-buy", "Minute sell transaction", "Minute sell", "Minute buy transaction", "Minute buy", "Minute total sell", "Minute absolute total buy"]
day_df_minute_final
# Out:
#                   Minute transaction  Minute sell-buy  \
# timestamp_minute
# 0                                 12           -56255
# 1                                 15           -75377
# 2                                  5            43805
# 3                                 17           -18577
# 4                                 11            89048
# 5                                 15            67830
# 6                                 16            46844
# 7                                 17           -14376
# 8                                 12           -48688
# 9                                 15           -69029
# 10                                18             1580
# 11                                10            76519
# 12                                19           -24074
# 13                                18            33322
# 14                                11            38111
# 15                                18           -22753
# 16                                21           -10057
# 17                                14              238
# 18                                12            -8785
# 19                                11           -51893
# 20                                14         -1392263
# 21                                18            13276
# 22                                10            12717
# 23                                19          1091660
# 24                                19           -26097
# 25                                10           -31848
# 26                                15            -8369
# 27                                12            24079
# 28                                10            -3003
# 29                                11           -34700
# 30                                14           -53498
# 31                                10            21926
# 32                                15            28289
# 33                                10            29348
# 34                                13           -23640
# 35                                10              658
# 36                                12            25832
# 37                                11           -11387
# 38                                14            40563
# 39                                14            11495
# 40                                16            -6380
# 41                                10           -87775
# 42                                16            22905
# 43                                12            -5119
# 44                                14          3264557
# 45                                11            40831
# 46                                16            53279
# 47                                19           102159
# 48                                13           -70635
# 49                                14           -21198
# 50                                15            41166
# 51                                17           -17803
# 52                                 9           -10248
# 53                                14           -27304
# 54                                11           -91966
# 55                                11           -70081
# 56                                15            51101
# 57                                16            -1376
# 58                                10            43296
# 59                                16           -37328
#
#                   Minute sell transaction  Minute sell  \
# timestamp_minute
# 0                                       4        58575
# 1                                       5        65860
# 2                                       4        57107
# 3                                       8       111805
# 4                                       8       129450
# 5                                      10       143395
# 6                                      10       137444
# 7                                       8       110655
# 8                                       5        56312
# 9                                       5        75368
# 10                                      9       130853
# 11                                      7       119468
# 12                                      9       123975
# 13                                     10       145261
# 14                                      7        97011
# 15                                      8       123198
# 16                                     10       146779
# 17                                      7        99557
# 18                                      6        83686
# 19                                      4        47860
# 20                                      9       135499
# 21                                      9       138884
# 22                                      6        76495
# 23                                     11      1199995
# 24                                      9       124918
# 25                                      4        53839
# 26                                      7       103346
# 27                                      7       100563
# 28                                      5        69342
# 29                                      4        62212
# 30                                      5        75808
# 31                                      6        84757
# 32                                      8       129618
# 33                                      6        82248
# 34                                      5        75842
# 35                                      5        71720
# 36                                      7        95701
# 37                                      5        70275
# 38                                      8       126106
# 39                                      7       111381
# 40                                      8       111773
# 41                                      2        28824
# 42                                      9       127485
# 43                                      6        81028
# 44                                      5      3388831
# 45                                      7        98465
# 46                                     10       147007
# 47                                     12       188634
# 48                                      4        59296
# 49                                      7        87387
# 50                                      9       126658
# 51                                      8       112693
# 52                                      4        59918
# 53                                      6        84964
# 54                                      2        33119
# 55                                      3        43226
# 56                                      9       131845
# 57                                      8       116922
# 58                                      6        87312
# 59                                      7        92343
#
#                   Minute buy transaction  Minute buy  Minute total sell  \
# timestamp_minute
# 0                                      8     -114830             173405
# 1                                     10     -141237             207097
# 2                                      1      -13302              70409
# 3                                      9     -130382             242187
# 4                                      3      -40402             169852
# 5                                      5      -75565             218960
# 6                                      6      -90600             228044
# 7                                      9     -125031             235686
# 8                                      7     -105000             161312
# 9                                     10     -144397             219765
# 10                                     9     -129273             260126
# 11                                     3      -42949             162417
# 12                                    10     -148049             272024
# 13                                     8     -111939             257200
# 14                                     4      -58900             155911
# 15                                    10     -145951             269149
# 16                                    11     -156836             303615
# 17                                     7      -99319             198876
# 18                                     6      -92471             176157
# 19                                     7      -99753             147613
# 20                                     5    -1527762            1663261
# 21                                     9     -125608             264492
# 22                                     4      -63778             140273
# 23                                     8     -108335            1308330
# 24                                    10     -151015             275933
# 25                                     6      -85687             139526
# 26                                     8     -111715             215061
# 27                                     5      -76484             177047
# 28                                     5      -72345             141687
# 29                                     7      -96912             159124
# 30                                     9     -129306             205114
# 31                                     4      -62831             147588
# 32                                     7     -101329             230947
# 33                                     4      -52900             135148
# 34                                     8      -99482             175324
# 35                                     5      -71062             142782
# 36                                     5      -69869             165570
# 37                                     6      -81662             151937
# 38                                     6      -85543             211649
# 39                                     7      -99886             211267
# 40                                     8     -118153             229926
# 41                                     8     -116599             145423
# 42                                     7     -104580             232065
# 43                                     6      -86147             167175
# 44                                     9     -124274            3513105
# 45                                     4      -57634             156099
# 46                                     6      -93728             240735
# 47                                     7      -86475             275109
# 48                                     9     -129931             189227
# 49                                     7     -108585             195972
# 50                                     6      -85492             212150
# 51                                     9     -130496             243189
# 52                                     5      -70166             130084
# 53                                     8     -112268             197232
# 54                                     9     -125085             158204
# 55                                     8     -113307             156533
# 56                                     6      -80744             212589
# 57                                     8     -118298             235220
# 58                                     4      -44016             131328
# 59                                     9     -129671             222014
#
#                   Minute absolute total buy
# timestamp_minute
# 0                                    114830
# 1                                    141237
# 2                                     13302
# 3                                    130382
# 4                                     40402
# 5                                     75565
# 6                                     90600
# 7                                    125031
# 8                                    105000
# 9                                    144397
# 10                                   129273
# 11                                    42949
# 12                                   148049
# 13                                   111939
# 14                                    58900
# 15                                   145951
# 16                                   156836
# 17                                    99319
# 18                                    92471
# 19                                    99753
# 20                                  1527762
# 21                                   125608
# 22                                    63778
# 23                                   108335
# 24                                   151015
# 25                                    85687
# 26                                   111715
# 27                                    76484
# 28                                    72345
# 29                                    96912
# 30                                   129306
# 31                                    62831
# 32                                   101329
# 33                                    52900
# 34                                    99482
# 35                                    71062
# 36                                    69869
# 37                                    81662
# 38                                    85543
# 39                                    99886
# 40                                   118153
# 41                                   116599
# 42                                   104580
# 43                                    86147
# 44                                   124274
# 45                                    57634
# 46                                    93728
# 47                                    86475
# 48                                   129931
# 49                                   108585
# 50                                    85492
# 51                                   130496
# 52                                    70166
# 53                                   112268
# 54                                   125085
# 55                                   113307
# 56                                    80744
# 57                                   118298
# 58                                    44016
# 59                                   129671

# %%
# date 별 계산 table 생성
dfs = [group_date_amount.size(), group_date_amount.sum(), group_date_amount_positive.size(), group_date_amount_positive.sum(), group_date_amount_negative.size(), group_date_amount_negative.sum(), absolute_date_total_amount, absolute_date_negative_sum]
day_df_date_final = reduce(lambda left,right: pd.merge(left,right,on='timestamp_day'), dfs)
day_df_date_final.columns = [ "Date transaction", "Date sell-buy", "Date sell transaction", "Date sell", "Date buy transaction", "Date buy", "Date total sell", "Date absolute total buy"]
day_df_date_final
# Out:
#                Date transaction  Date sell-buy  Date sell transaction  \
# timestamp_day
# 19                           40        1052348                     21
# 20                          153            426                     76
# 21                          154          -1741                     76
# 22                           69         -14922                     34
# 23                           96            899                     48
# 24                           86          -1680                     42
# 25                          217          11247                    109
# 31                            4            -86                      2
#
#                Date sell  Date buy transaction  Date buy  Date total sell  \
# timestamp_day
# 19               1334332                    19   -281984        1616316.0
# 20               1239191                    77  -1238765        2477956.0
# 21               1201705                    78  -1203446        2405151.0
# 22                480676                    35   -495598         976274.0
# 23                633072                    48   -632173        1265245.0
# 24                565300                    44   -566980        1132280.0
# 25               1442316                   108  -1431069        2873385.0
# 31                 22176                     2    -22262          44438.0
#
#                Date absolute total buy
# timestamp_day
# 19                              281984
# 20                             1238765
# 21                             1203446
# 22                              495598
# 23                              632173
# 24                              566980
# 25                             1431069
# 31                               22262

# %%
# table 저장하기
day_df_minute_final.to_csv("/Users/hamin/ITE3035_Python/Data_Science/table/minute_result_table_2018_01.csv", header=True, index=True, encoding = 'utf-8')

# %%
# table 저장하기
day_df_date_final.to_csv("/Users/hamin/ITE3035_Python/Data_Science/table/date_result_table_2018_01.csv", header=True, index=True, encoding = 'utf-8')

# %%
# Minute - transaction 그래프 그리기
day_df_minute_final[['Minute transaction', 'Minute sell transaction', 'Minute buy transaction']].plot(title='Transaction count per minute', marker='o')
plt.savefig('/Users/hamin/ITE3035_Python/Data_Science/graph/Transaction_count_per_minute_2018_01.png', dpi=300)

# %%
minuteTransGraph = day_df_minute_final[['Minute sell transaction', 'Minute buy transaction']].plot.bar(title='Transaction count per minute 2018 01', stacked=True)
minuteTransGraph.set_xlabel('Minute')
minuteTransGraph.set_ylabel('Transaction')
minuteTransGraph.set_xticklabels(['$0$','','','','','','','','','','$10$','','','','','','','','','','$20$','','','','','','','','','','$30$','','','','','','','','','','$40$','','','','','','','','','','$50$'])
plt.savefig('/Users/hamin/ITE3035_Python/Data_Science/graph/Transaction_count_per_minute(Stacked)_2018_01.png', dpi=300)

# %%
minuteTransBarGraph = day_df_minute_final[['Minute sell transaction', 'Minute buy transaction']].plot.bar(title='Transaction count per minute(Bar) 2018 01')
minuteTransBarGraph.set_xlabel('Minute')
minuteTransBarGraph.set_ylabel('Transaction')
minuteTransBarGraph.set_xticklabels(['$0$','','','','','','','','','','$10$','','','','','','','','','','$20$','','','','','','','','','','$30$','','','','','','','','','','$40$','','','','','','','','','','$50$'])
plt.savefig('/Users/hamin/ITE3035_Python/Data_Science/graph/Transaction_count_per_minute(Bar)_2018_01.png', dpi=300)

# %%
# Date - transaction 그래프 그리기
day_df_date_final[['Date transaction', 'Date sell transaction', 'Date buy transaction']].plot(title='Transaction count per day 2018-01', marker='o')
plt.savefig('/Users/hamin/ITE3035_Python/Data_Science/graph/Transaction_count_per_day_2018_01.png', dpi=300)

# %%
dayTransGraph = day_df_date_final[['Date sell transaction', 'Date buy transaction']].plot.bar(title='Transaction count per day 2018-01', stacked=True)
dayTransGraph.set_xlabel('Date')
dayTransGraph.set_ylabel('Transaction')
plt.savefig('/Users/hamin/ITE3035_Python/Data_Science/graph/Transaction_count_per_day(Stacked)_2018_01.png', dpi=300)

# %%
dayTransBarGraph = day_df_date_final[['Date sell transaction', 'Date buy transaction']].plot.bar(title='Transaction count per day(Bar) 2018-01')
dayTransBarGraph.set_xlabel('Date')
dayTransBarGraph.set_ylabel('Transaction')
plt.savefig('/Users/hamin/ITE3035_Python/Data_Science/graph/Transaction_count_per_day(Bar)_2018_01.png', dpi=300)
