# %%
import pandas as pd
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, savefig
import time
import csv
import sys
import plotly.express as px

# %%
df = pd.read_csv("/Users/hamin/bithumb_bot_data/include/2018-new/2018-08-btc-krw.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d5da1c0bcede> in <module>
# ----> 1 df = pd.read_csv("/Users/hamin/bithumb_bot_data/include/2018-new/2018-08-btc-krw.csv")
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File /Users/hamin/bithumb_bot_data/include/2018-new/2018-08-btc-krw.csv does not exist: '/Users/hamin/bithumb_bot_data/include/2018-new/2018-08-btc-krw.csv'

# %%
df.dtypes

# %%
## converting timestamp column type 'object' to 'datetime'
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d %H:%M:%S', errors='raise')
df.dtypes

# %%
## converting timestamp to detailed date column
df['timestamp_year_month_day']       = df['timestamp'].dt.date         # YYYY-MM-DD(문자)
df['timestamp_year']       = df['timestamp'].dt.year         # 연(4자리숫자)
df['timestamp_month']      = df['timestamp'].dt.month        # 월(숫자)
df['timestamp_month_name'] = df['timestamp'].dt.month_name() # 월(문자)

df['timestamp_day']        = df['timestamp'].dt.day          # 일(숫자)
df['timestamp_time']       = df['timestamp'].dt.time         # HH:MM:SS(문자)
df['timestamp_hour']       = df['timestamp'].dt.hour         # 시(숫자)
df['timestamp_minute']     = df['timestamp'].dt.minute       # 분(숫자)
df['timestamp_second']     = df['timestamp'].dt.second       # 초(숫자)

# %%
df

# %%
## creating 'day - amount' connection
group_day_amount = df['amount'].groupby(df['timestamp_year_month_day'])

# %%
group_day_amount.size()

# %%
group_day_amount

# %%
## 일별 총 손익량
group_day_amount.sum()

# %%
## creating 'day - earning amount' connection
df2 = df.copy()
df2 =df2[df2['amount'] > 0]
group_day_amount_positive = df2['amount'].groupby(df2['timestamp_year_month_day'])

# %%
# 일별 수익 transaction 수
group_day_amount_positive.size()

# %%
# 일별 수익량
group_day_amount_positive.sum()

# %%
## creating 'day - loss amount' connection
df3 = df.copy()
df3 = df3[df3['amount'] < 0]
group_day_amount_negative = df3['amount'].groupby(df3['timestamp_year_month_day'])

# %%
# 일별 손해 transaction 수
group_day_amount_negative.size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7e892e835da3> in <module>
#       1 # 일별 손해 transaction 수
# ----> 2 group_day_amount_negative.size()
#
# NameError: name 'group_day_amount_negative' is not defined

# %%
# 일별 손해량
group_day_amount_negative.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4d186221ce6f> in <module>
#       1 # 일별 손해량
# ----> 2 group_day_amount_negative.sum()
#
# NameError: name 'group_day_amount_negative' is not defined

# %%
# 일별 절대값 총합
absolute_negative_sum=group_day_amount_negative.sum()
absolute_negative_sum = absolute_negative_sum * (-1)
absolute_total_amout=absolute_negative_sum+group_day_amount_positive.sum()
absolute_total_amout
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8f7fe7191ee3> in <module>
#       1 # 일별 절대값 총합
# ----> 2 absolute_negative_sum=group_day_amount_negative.sum()
#       3 absolute_negative_sum = absolute_negative_sum * (-1)
#       4 absolute_total_amout=absolute_negative_sum+group_day_amount_positive.sum()
#       5 absolute_total_amout
#
# NameError: name 'group_day_amount_negative' is not defined

# %%
## 일별 계산 table 생성
dfs = [group_day_amount.size(), group_day_amount.sum(), group_day_amount_positive.size(), group_day_amount_positive.sum(), group_day_amount_negative.size(), group_day_amount_negative.sum(), absolute_total_amout, absolute_negative_sum]
dfs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e81f069f54ae> in <module>
#       1 ## 일별 계산 table 생성
# ----> 2 dfs = [group_day_amount.size(), group_day_amount.sum(), group_day_amount_positive.size(), group_day_amount_positive.sum(), group_day_amount_negative.size(), group_day_amount_negative.sum(), absolute_total_amout, absolute_negative_sum]
#       3 dfs
#
# NameError: name 'group_day_amount' is not defined

# %%
day_df_final = reduce(lambda left,right: pd.merge(left,right,on='timestamp_year_month_day'), dfs)
day_df_final.columns = [ "daily transaction", "daily income", "daily Yield transaction", "daily Yield", "daily loss transaction", "daily loss", "daily absolute amount", "daily absolute negative amount"]
day_df_final
# Out:
#                           daily transaction  daily income  \
# timestamp_year_month_day
# 2018-05-01                              505     -17802234
# 2018-05-02                              407       8295332
# 2018-05-03                              527      10138584
# 2018-05-04                             1002        545803
# 2018-05-05                              559        340552
# 2018-05-06                              689     -15021496
# 2018-05-07                             1015      -9802781
# 2018-05-08                             1157      -4478454
# 2018-05-09                             1061      32020288
# 2018-05-10                              498     -15454910
# 2018-05-11                             1106      15948021
# 2018-05-12                             1494        716218
# 2018-05-13                             1415        506235
# 2018-05-14                             1185        748015
# 2018-05-15                             1293       -642716
# 2018-05-16                             1284     -33671859
# 2018-05-17                              928      35135338
# 2018-05-18                              922        827709
# 2018-05-19                              573        722379
# 2018-05-20                              506     -26828987
# 2018-05-21                              624      28321486
# 2018-05-22                              484     -23719995
# 2018-05-23                              703      23599623
# 2018-05-24                              885     -12506828
# 2018-05-25                              487      12749313
# 2018-05-26                              257     -13815553
# 2018-05-27                              222       3720588
# 2018-05-28                              311      -5858398
# 2018-05-29                              448      16548664
# 2018-05-30                              378        187538
# 2018-05-31                              370        531831
#
#                           daily Yield transaction  daily Yield  \
# timestamp_year_month_day
# 2018-05-01                                    302    717288802
# 2018-05-02                                    212    556368315
# 2018-05-03                                    291    853401686
# 2018-05-04                                    581   1812511408
# 2018-05-05                                    321    955927119
# 2018-05-06                                    447   1079537488
# 2018-05-07                                    720   1633907661
# 2018-05-08                                    796   2261280750
# 2018-05-09                                    668   1790217680
# 2018-05-10                                    289    918973913
# 2018-05-11                                    710   1748230958
# 2018-05-12                                    950   1844350809
# 2018-05-13                                    916   1876379212
# 2018-05-14                                    714   2061334907
# 2018-05-15                                    945   2460913560
# 2018-05-16                                    828   2052901506
# 2018-05-17                                    602   1546594426
# 2018-05-18                                    649   1514323102
# 2018-05-19                                    362    889631353
# 2018-05-20                                    330    789460214
# 2018-05-21                                    395    954023745
# 2018-05-22                                    351    833107084
# 2018-05-23                                    485   1147547739
# 2018-05-24                                    500   1055529545
# 2018-05-25                                    294    681984676
# 2018-05-26                                    172    261136899
# 2018-05-27                                    138    237710205
# 2018-05-28                                    188    431632616
# 2018-05-30                                     580364520
# 2018-05-31                                     562982934

# %%
day_df_final.to_csv("/Users/hamin/bithumb_bot_data/2018-08-daily_result_table.csv", header=True, index=True, encoding = 'utf-8')

# %%
# 뒤집기.
day_df_final[::-1].to_csv("/Users/hamin/bithumb_bot_data/2018-08-daily_result_table.csv", header=True, index=True, encoding = 'utf-8')

# %%
day_df_final
# Out:
#                           daily transaction  daily income  \
# timestamp_year_month_day
# 2018-05-01                              505     -17802234
# 2018-05-02                              407       8295332
# 2018-05-03                              527      10138584
# 2018-05-04                             1002        545803
# 2018-05-05                              559        340552
# 2018-05-06                              689     -15021496
# 2018-05-07                             1015      -9802781
# 2018-05-08                             1157      -4478454
# 2018-05-09                             1061      32020288
# 2018-05-10                              498     -15454910
# 2018-05-11                             1106      15948021
# 2018-05-12                             1494        716218
# 2018-05-13                             1415        506235
# 2018-05-14                             1185        748015
# 2018-05-15                             1293       -642716
# 2018-05-16                             1284     -33671859
# 2018-05-17                              928      35135338
# 2018-05-18                              922        827709
# 2018-05-19                              573        722379
# 2018-05-20                              506     -26828987
# 2018-05-21                              624      28321486
# 2018-05-22                              484     -23719995
# 2018-05-23                              703      23599623
# 2018-05-24                              885     -12506828
# 2018-05-25                              487      12749313
# 2018-05-26                              257     -13815553
# 2018-05-27                              222       3720588
# 2018-05-28                              311      -5858398
# 2018-05-29                              448      16548664
# 2018-05-30                              378        187538
# 2018-05-31                              370        531831
#
#                           daily Yield transaction  daily Yield  \
# timestamp_year_month_day
# 2018-05-01                                    302    717288802
# 2018-05-02                                    212    556368315
# 2018-05-03                                    291    853401686
# 2018-05-04                                    581   1812511408
# 2018-05-05                                    321    955927119
# 2018-05-06                                    447   1079537488
# 2018-05-07                                    720   1633907661
# 2018-05-08                                    796   2261280750
# 2018-05-09                                    668   1790217680
# 2018-05-10                                    289    918973913
# 2018-05-11                                    710   1748230958
# 2018-05-12                                    950   1844350809
# 2018-05-13                                    916   1876379212
# 2018-05-14                                    714   2061334907
# 2018-05-15                                    945   2460913560
# 2018-05-16                                    828   2052901506
# 2018-05-17                                    602   1546594426
# 2018-05-18                                    649   1514323102
# 2018-05-19                                    362    889631353
# 2018-05-20                                    330    789460214
# 2018-05-21                                    395    954023745
# 2018-05-22                                    351    833107084
# 2018-05-23                                    485   1147547739
# 2018-05-24                                    500   1055529545
# 2018-05-25                                    294    681984676
# 2018-05-26                                    172    261136899
# 2018-05-27                                    138    237710205
# 2018-05-28                                    188    431632616
# 2018-05-29                                    251    524002315
# 2018-05-30                                    216    580552058
# 2018-05-31                                    245    563514765
#
#                           daily loss transaction  daily loss  \
# timestamp_year_month_day
# 2018-05-01                                   203  -735091036
# 2018-05-02                                   195  -548072983
# 2018-05-03                                   236  -843263102
# 2018-05-04                                   421 -1811965605
# 2018-05-05                                   238  -955586567
# 2018-05-06                                   242 -1094558984
