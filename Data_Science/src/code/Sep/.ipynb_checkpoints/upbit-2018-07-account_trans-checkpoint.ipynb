# %%
import pandas as pd
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, savefig
import time
import csv
import sys
import plotly.express as px

# %%
df = pd.read_csv("/Users/hamin/bithumb_bot_data/include/up-btc/upbit-2018-07-btc-krw.csv")

# %%
df.dtypes
# Out:
# timestamp     object
# quantity     float64
# price        float64
# fee          float64
# amount         int64
# side         float64
# dtype: object

# %%
## converting timestamp column type 'object' to 'datetime'
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d %H:%M:%S', errors='raise')
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1857         try:
# -> 1858             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1859             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-10abec2e604a> in <module>
#       1 ## converting timestamp column type 'object' to 'datetime'
# ----> 2 df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d %H:%M:%S', errors='raise')
#       3 df.dtypes
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     722                 result = result.tz_localize(tz)
#     723     elif isinstance(arg, ABCSeries):
# --> 724         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     725         if not cache_array.empty:
#     726             result = arg.map(cache_array)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     150         unique_dates = unique(arg)
#     151         if len(unique_dates) < len(arg):
# --> 152             cache_dates = convert_listlike(unique_dates, format)
#     153             cache_array = Series(cache_dates, index=unique_dates)
#     154     return cache_array
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     445             errors=errors,
#     446             require_iso8601=require_iso8601,
# --> 447             allow_object=True,
#     448         )
#     449
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1861             return values.view("i8"), tz_parsed
#    1862         except (ValueError, TypeError):
# -> 1863             raise e
#    1864
#    1865     if tz_parsed is not None:
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1852             dayfirst=dayfirst,
#    1853             yearfirst=yearfirst,
# -> 1854             require_iso8601=require_iso8601,
#    1855         )
#    1856     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ValueError: time data 0.50000000 doesn't match format specified

# %%
## converting timestamp to detailed date column
df['timestamp_year_month_day']       = df['timestamp'].dt.date         # YYYY-MM-DD(문자)
df['timestamp_year']       = df['timestamp'].dt.year         # 연(4자리숫자)
df['timestamp_month']      = df['timestamp'].dt.month        # 월(숫자)
df['timestamp_month_name'] = df['timestamp'].dt.month_name() # 월(문자)

df['timestamp_day']        = df['timestamp'].dt.day          # 일(숫자)
df['timestamp_time']       = df['timestamp'].dt.time         # HH:MM:SS(문자)
df['timestamp_hour']       = df['timestamp'].dt.hour         # 시(숫자)
df['timestamp_minute']     = df['timestamp'].dt.minute       # 분(숫자)
df['timestamp_second']     = df['timestamp'].dt.second       # 초(숫자)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ae3f5e8f099d> in <module>
#       1 ## converting timestamp to detailed date column
# ----> 2 df['timestamp_year_month_day']       = df['timestamp'].dt.date         # YYYY-MM-DD(문자)
#       3 df['timestamp_year']       = df['timestamp'].dt.year         # 연(4자리숫자)
#       4 df['timestamp_month']      = df['timestamp'].dt.month        # 월(숫자)
#       5 df['timestamp_month_name'] = df['timestamp'].dt.month_name() # 월(문자)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # http://www.pydanny.com/cached-property.html
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     336             return DatetimeProperties(data, orig)
#     337
# --> 338         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
df
# Out:
#               timestamp  quantity      price      fee   amount  side
# 0      2018.07.02 18:20  0.001303  7085000.0     4.61     9228   1.0
# 1      2018.07.02 23:18  0.011700  7346000.0    42.97    85905   1.0
# 2      2018.07.02 23:20  0.001000  7301000.0     3.65    -7305   0.0
# 3      2018.07.02 23:22  0.001000  7297000.0     3.64     7293   1.0
# 4      2018.07.02 23:22  0.001000  7301000.0     3.65    -7305   0.0
# ...                 ...       ...        ...      ...      ...   ...
# 19095  2018.07.31 23:55  0.035118  8780000.0   154.16  -308492   0.0
# 19096  2018.07.31 23:58  0.003167  8796000.0    13.92    27845   1.0
# 19097  2018.07.31 23:58  0.008987  8796000.0    39.52    79007   1.0
# 19098  2018.07.31 23:58  0.260176  8796000.0  1144.25  2287364   1.0
# 19099  2018.07.31 23:58  0.093075  8796000.0   409.34   818274   1.0
#
# [19100 rows x 6 columns]

# %%
## creating 'day - amount' connection
group_day_amount = df['amount'].groupby(df['timestamp_year_month_day'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp_year_month_day'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-4460dcf97a94> in <module>
#       1 ## creating 'day - amount' connection
# ----> 2 group_day_amount = df['amount'].groupby(df['timestamp_year_month_day'])
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp_year_month_day'

# %%
group_day_amount.size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1df64d163210> in <module>
# ----> 1 group_day_amount.size()
#
# NameError: name 'group_day_amount' is not defined

# %%
group_day_amount

# %%
## 일별 총 손익량
group_day_amount.sum()
# Out:
# timestamp_year_month_day
# 2018-01-03    3341130
# 2018-01-10   -1468934
# 2018-01-11     -19563
# 2018-01-18     -14572
# 2018-01-19    1052348
# 2018-01-20        426
# 2018-01-21      -1741
# 2018-01-22     -14922
# 2018-01-23        899
# 2018-01-24      -1680
# 2018-01-25      11247
# 2018-01-31        -86
# Name: amount, dtype: int64

# %%
## creating 'day - earning amount' connection
df2 = df.copy()
df2 =df2[df2['amount'] > 0]
group_day_amount_positive = df2['amount'].groupby(df2['timestamp_year_month_day'])

# %%
# 일별 수익 transaction 수
group_day_amount_positive.size()
# Out:
# timestamp_year_month_day
# 2018-01-03      1
# 2018-01-19     21
# 2018-01-20     76
# 2018-01-21     76
# 2018-01-22     34
# 2018-01-23     48
# 2018-01-24     42
# 2018-01-25    109
# 2018-01-31      2
# Name: amount, dtype: int64

# %%
# 일별 수익량
group_day_amount_positive.sum()
# Out:
# timestamp_year_month_day
# 2018-01-03    3341130
# 2018-01-19    1334332
# 2018-01-20    1239191
# 2018-01-21    1201705
# 2018-01-22     480676
# 2018-01-23     633072
# 2018-01-24     565300
# 2018-01-25    1442316
# 2018-01-31      22176
# Name: amount, dtype: int64

# %%
## creating 'day - loss amount' connection
df3 = df.copy()
df3 = df3[df3['amount'] < 0]
group_day_amount_negative = df3['amount'].groupby(df3['timestamp_year_month_day'])

# %%
# 일별 손해 transaction 수
group_day_amount_negative.size()
# Out:
# timestamp_year_month_day
# 2018-01-10      1
# 2018-01-11      1
# 2018-01-18      1
# 2018-01-19     19
# 2018-01-20     77
# 2018-01-21     78
# 2018-01-22     35
# 2018-01-23     48
# 2018-01-24     44
# 2018-01-25    108
# 2018-01-31      2
# Name: amount, dtype: int64

# %%
# 일별 손해량
group_day_amount_negative.sum()
# Out:
# timestamp_year_month_day
# 2018-01-10   -1468934
# 2018-01-11     -19563
# 2018-01-18     -14572
# 2018-01-19    -281984
# 2018-01-20   -1238765
# 2018-01-21   -1203446
# 2018-01-22    -495598
# 2018-01-23    -632173
# 2018-01-24    -566980
# 2018-01-25   -1431069
# 2018-01-31     -22262
# Name: amount, dtype: int64

# %%
# 일별 절대값 총합
absolute_negative_sum=group_day_amount_negative.sum()
absolute_negative_sum = absolute_negative_sum * (-1)
absolute_total_amout=absolute_negative_sum+group_day_amount_positive.sum()
absolute_total_amout
# Out:
# timestamp_year_month_day
# 2018-01-03          NaN
# 2018-01-10          NaN
# 2018-01-11          NaN
# 2018-01-18          NaN
# 2018-01-19    1616316.0
# 2018-01-20    2477956.0
# 2018-01-21    2405151.0
# 2018-01-22     976274.0
# 2018-01-23    1265245.0
# 2018-01-24    1132280.0
# 2018-01-25    2873385.0
# 2018-01-31      44438.0
# Name: amount, dtype: float64

# %%
## 일별 계산 table 생성
dfs = [group_day_amount.size(), group_day_amount.sum(), group_day_amount_positive.size(), group_day_amount_positive.sum(), group_day_amount_negative.size(), group_day_amount_negative.sum(), absolute_total_amout, absolute_negative_sum]
dfs
# Out:
# [timestamp_year_month_day
#  2018-01-03      1
#  2018-01-10      1
#  2018-01-11      1
#  2018-01-18      1
#  2018-01-19     40
#  2018-01-20    153
#  2018-01-21    154
#  2018-01-22     69
#  2018-01-23     96
#  2018-01-24     86
#  2018-01-25    217
#  2018-01-31      4
#  Name: amount, dtype: int64,
#  timestamp_year_month_day
#  2018-01-03    3341130
#  2018-01-10   -1468934
#  2018-01-11     -19563
#  2018-01-18     -14572
#  2018-01-19    1052348
#  2018-01-20        426
#  2018-01-21      -1741
#  2018-01-22     -14922
#  2018-01-23        899
#  2018-01-24      -1680
#  2018-01-25      11247
#  2018-01-31        -86
#  Name: amount, dtype: int64,
#  timestamp_year_month_day
#  2018-01-03      1
#  2018-01-19     21
#  2018-01-20     76
#  2018-01-21     76
#  2018-01-22     34
#  2018-01-23     48
#  2018-01-24     42
#  2018-01-25    109
#  2018-01-31      2
#  Name: amount, dtype: int64,
#  timestamp_year_month_day
#  2018-01-03    3341130
#  2018-01-19    1334332
#  2018-01-20    1239191
#  2018-01-21    1201705
#  2018-01-22     480676
#  2018-01-23     633072
#  2018-01-24     565300
#  2018-01-25    1442316
#  2018-01-31      22176
#  Name: amount, dtype: int64,
#  timestamp_year_month_day
#  2018-01-10      1
#  2018-01-11      1
#  2018-01-18      1
#  2018-01-19     19
#  2018-01-20     77
#  2018-01-21     78
#  2018-01-22     35
#  2018-01-23     48
#  2018-01-24     44
#  2018-01-25    108
#  2018-01-31      2
#  Name: amount, dtype: int64,
#  timestamp_year_month_day
#  2018-01-10   -1468934
#  2018-01-11     -19563
#  2018-01-18     -14572
#  2018-01-19    -281984
#  2018-01-20   -1238765
#  2018-01-21   -1203446
#  2018-01-22    -495598
#  2018-01-23    -632173
#  2018-01-24    -566980
#  2018-01-25   -1431069
#  2018-01-31     -22262
#  Name: amount, dtype: int64,
#  timestamp_year_month_day
#  2018-01-03          NaN
#  2018-01-10          NaN
#  2018-01-11          NaN
#  2018-01-18          NaN
#  2018-01-19    1616316.0
#  2018-01-20    2477956.0
#  2018-01-21    2405151.0
#  2018-01-22     976274.0
#  2018-01-23    1265245.0
#  2018-01-24    1132280.0
#  2018-01-25    2873385.0
#  2018-01-31      44438.0
#  Name: amount, dtype: float64,
#  timestamp_year_month_day
#  2018-01-10    1468934
#  2018-01-11      19563
#  2018-01-18      14572
#  2018-01-19     281984
#  2018-01-20    1238765
#  2018-01-21    1203446
#  2018-01-22     495598
#  2018-01-23     632173
#  2018-01-24     566980
#  2018-01-25    1431069
#  2018-01-31      22262
#  Name: amount, dtype: int64]

# %%
day_df_final = reduce(lambda left,right: pd.merge(left,right,on='timestamp_year_month_day'), dfs)
day_df_final.columns = [ "daily transaction", "daily income", "daily Yield transaction", "daily Yield", "daily loss transaction", "daily loss", "daily absolute amount", "daily absolute negative amount"]
day_df_final
# Out:
#                           daily transaction  daily income  \
# timestamp_year_month_day
# 2018-01-19                               40       1052348
# 2018-01-20                              153           426
# 2018-01-21                              154         -1741
# 2018-01-22                               69        -14922
# 2018-01-23                               96           899
# 2018-01-24                               86         -1680
# 2018-01-25                              217         11247
# 2018-01-31                                4           -86
#
#                           daily Yield transaction  daily Yield  \
# timestamp_year_month_day
# 2018-01-19                                     21      1334332
# 2018-01-20                                     76      1239191
# 2018-01-21                                     76      1201705
# 2018-01-22                                     34       480676
# 2018-01-23                                     48       633072
# 2018-01-24                                     42       565300
# 2018-01-25                                    109      1442316
# 2018-01-31                                      2        22176
#
#                           daily loss transaction  daily loss  \
# timestamp_year_month_day
# 2018-01-19                                    19     -281984
# 2018-01-20                                    77    -1238765
# 2018-01-21                                    78    -1203446
# 2018-01-22                                    35     -495598
# 2018-01-23                                    48     -632173
# 2018-01-24                                    44     -566980
# 2018-01-25                                   108    -1431069
# 2018-01-31                                     2      -22262
#
#                           daily absolute amount  \
# timestamp_year_month_day
# 2018-01-19                            1616316.0
# 2018-01-20                            2477956.0
# 2018-01-21                            2405151.0
# 2018-01-22                             976274.0
# 2018-01-23                            1265245.0
# 2018-01-24                            1132280.0
# 2018-01-25                            2873385.0
# 2018-01-31                              44438.0
#
#                           daily absolute negative amount
# timestamp_year_month_day
# 2018-01-19                                        281984
# 2018-01-20                                       1238765
# 2018-01-21                                       1203446
# 2018-01-22                                        495598
# 2018-01-23                                        632173
# 2018-01-24                                        566980
# 2018-01-25                                       1431069
# 2018-01-31                                         22262

# %%
print(day_df_final.asfreq('D'))
# Out:
#                           daily transaction  daily income  \
# timestamp_year_month_day
# 2018-01-19                             40.0     1052348.0
# 2018-01-20                            153.0         426.0
# 2018-01-21                            154.0       -1741.0
# 2018-01-22                             69.0      -14922.0
# 2018-01-23                             96.0         899.0
# 2018-01-24                             86.0       -1680.0
# 2018-01-25                            217.0       11247.0
# 2018-01-26                              NaN           NaN
# 2018-01-27                              NaN           NaN
# 2018-01-28                              NaN           NaN
# 2018-01-29                              NaN           NaN
# 2018-01-30                              NaN           NaN
# 2018-01-31                              4.0         -86.0
#
#                           daily Yield transaction  daily Yield  \
# timestamp_year_month_day
# 2018-01-19                                   21.0    1334332.0
# 2018-01-20                                   76.0    1239191.0
# 2018-01-21                                   76.0    1201705.0
# 2018-01-22                                   34.0     480676.0
# 2018-01-23                                   48.0     633072.0
# 2018-01-24                                   42.0     565300.0
# 2018-01-25                                  109.0    1442316.0
# 2018-01-26                                    NaN          NaN
# 2018-01-27                                    NaN          NaN
# 2018-01-28                                    NaN          NaN
# 2018-01-29                                    NaN          NaN
# 2018-01-30                                    NaN          NaN
# 2018-01-31                                    2.0      22176.0
#
#                           daily loss transaction  daily loss  \
# timestamp_year_month_day
# 2018-01-19                                  19.0   -281984.0
# 2018-01-20                                  77.0  -1238765.0
# 2018-01-21                                  78.0  -1203446.0
# 2018-01-22                                  35.0   -495598.0
# 2018-01-23                                  48.0   -632173.0
# 2018-01-24                                  44.0   -566980.0
# 2018-01-25                                 108.0  -1431069.0
# 2018-01-26                                   NaN         NaN
# 2018-01-27                                   NaN         NaN
# 2018-01-28                                   NaN         NaN
# 2018-01-29                                   NaN         NaN
# 2018-01-30                                   NaN         NaN
# 2018-01-31                                   2.0    -22262.0
#
#                           daily absolute amount  \
# timestamp_year_month_day
# 2018-01-19                            1616316.0
# 2018-01-20                            2477956.0
# 2018-01-21                            2405151.0
# 2018-01-22                             976274.0
# 2018-01-23                            1265245.0
# 2018-01-24                            1132280.0
# 2018-01-25                            2873385.0
# 2018-01-26                                  NaN
# 2018-01-27                                  NaN
# 2018-01-28                                  NaN
# 2018-01-29                                  NaN
# 2018-01-30                                  NaN
# 2018-01-31                              44438.0
#
#                           daily absolute negative amount
# timestamp_year_month_day
# 2018-01-19                                      281984.0
# 2018-01-20                                     1238765.0
# 2018-01-21                                     1203446.0
# 2018-01-22                                      495598.0
# 2018-01-23                                      632173.0
# 2018-01-24                                      566980.0
# 2018-01-25                                     1431069.0
# 2018-01-26                                           NaN
# 2018-01-27                                           NaN
# 2018-01-28                                           NaN
# 2018-01-29                                           NaN
# 2018-01-30                                           NaN
# 2018-01-31                                       22262.0

# %%
day_df_final.to_csv("/Users/hamin/bithumb_bot_data/2018-01-daily_result_table.csv", header=True, index=True, encoding = 'utf-8')

# %%
# 뒤집기.
day_df_final[::-1].to_csv("/Users/hamin/bithumb_bot_data/2018-01-daily_result_table.csv", header=True, index=True, encoding = 'utf-8')

# %%
day_df_final
# Out:
#                           daily transaction  daily income  \
# timestamp_year_month_day
# 2018-01-19                               40       1052348
# 2018-01-20                              153           426
# 2018-01-21                              154         -1741
# 2018-01-22                               69        -14922
# 2018-01-23                               96           899
# 2018-01-24                               86         -1680
# 2018-01-25                              217         11247
# 2018-01-31                                4           -86
#
#                           daily Yield transaction  daily Yield  \
# timestamp_year_month_day
# 2018-01-19                                     21      1334332
# 2018-01-20                                     76      1239191
# 2018-01-21                                     76      1201705
# 2018-01-22                                     34       480676
# 2018-01-23                                     48       633072
# 2018-01-24                                     42       565300
# 2018-01-25                                    109      1442316
# 2018-01-31                                      2        22176
#
#                           daily loss transaction  daily loss  \
# timestamp_year_month_day
# 2018-01-19                                    19     -281984
# 2018-01-20                                    77    -1238765
# 2018-01-21                                    78    -1203446
# 2018-01-22                                    35     -495598
# 2018-01-23                                    48     -632173
# 2018-01-24                                    44     -566980
# 2018-01-25                                   108    -1431069
# 2018-01-31                                     2      -22262
#
#                           daily absolute amount  \
# timestamp_year_month_day
# 2018-01-19                            1616316.0
# 2018-01-20                            2477956.0
# 2018-01-21                            2405151.0
# 2018-01-22                             976274.0
# 2018-01-23                            1265245.0
# 2018-01-24                            1132280.0
# 2018-01-25                            2873385.0
# 2018-01-31                              44438.0
#
#                           daily absolute negative amount
# timestamp_year_month_day
# 2018-01-19                                        281984
# 2018-01-20                                       1238765
# 2018-01-21                                       1203446
# 2018-01-22                                        495598
# 2018-01-23                                        632173
# 2018-01-24                                        566980
# 2018-01-25                                       1431069
# 2018-01-31                                         22262
