# %%
import pandas as pd
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, savefig
import time
import csv
import sys
import plotly.express as px

# %%
df = pd.read_csv("/Users/hamin/bithumb_bot_data/include/up-btc/upbit-2018-12-btc-krw.csv")

# %%
df.dtypes
# Out:
# timestamp     object
# quantity     float64
# price          int64
# fee          float64
# amount         int64
# side           int64
# dtype: object

# %%
## converting timestamp column type 'object' to 'datetime'
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d %H:%M:%S', errors='raise')
df.dtypes
# Out:
# timestamp    datetime64[ns]
# quantity            float64
# price                 int64
# fee                 float64
# amount                int64
# side                  int64
# dtype: object

# %%
## converting timestamp to detailed date column
df['timestamp_year_month_day']       = df['timestamp'].dt.date         # YYYY-MM-DD(문자)
df['timestamp_year']       = df['timestamp'].dt.year         # 연(4자리숫자)
df['timestamp_month']      = df['timestamp'].dt.month        # 월(숫자)
df['timestamp_month_name'] = df['timestamp'].dt.month_name() # 월(문자)

df['timestamp_day']        = df['timestamp'].dt.day          # 일(숫자)
df['timestamp_time']       = df['timestamp'].dt.time         # HH:MM:SS(문자)
df['timestamp_hour']       = df['timestamp'].dt.hour         # 시(숫자)
df['timestamp_minute']     = df['timestamp'].dt.minute       # 분(숫자)
df['timestamp_second']     = df['timestamp'].dt.second       # 초(숫자)

# %%
df
# Out:
#                timestamp  quantity    price      fee   amount  side  \
# 0    2018-12-02 01:27:00  0.002100  4817000     5.05   -10121     0
# 1    2018-12-02 01:30:00  0.002100  4821000     5.06    10119     1
# 2    2018-12-02 02:02:00  0.448918  4816000  1080.99 -2163071     0
# 3    2018-12-02 02:02:00  0.009058  4816000    21.81   -43646     0
# 4    2018-12-02 02:02:00  0.115024  4816000   276.97  -554232     0
# ...                  ...       ...      ...      ...      ...   ...
# 3667 2018-12-28 09:34:00  0.058000  4107000   119.10   238086     1
# 3668 2018-12-28 09:35:00  0.004300  4101000     8.81    17625     1
# 3669 2018-12-28 09:35:00  0.980000  4101000  2009.49  4016970     1
# 3670 2018-12-28 09:41:00  0.041716  4093000    85.37   170660     1
# 3671 2018-12-28 09:41:00  1.501584  4093000  3072.99  6142908     1
#
#      timestamp_year_month_day  timestamp_year  timestamp_month  \
# 0                  2018-12-02            2018               12
# 1                  2018-12-02            2018               12
# 2                  2018-12-02            2018               12
# 3                  2018-12-02            2018               12
# 4                  2018-12-02            2018               12
# ...                       ...             ...              ...
# 3667               2018-12-28            2018               12
# 3668               2018-12-28            2018               12
# 3669               2018-12-28            2018               12
# 3670               2018-12-28            2018               12
# 3671               2018-12-28            2018               12
#
#      timestamp_month_name  timestamp_day timestamp_time  timestamp_hour  \
# 0                December              2       01:27:00               1
# 1                December              2       01:30:00               1
# 2                December              2       02:02:00               2
# 3                December              2       02:02:00               2
# 4                December              2       02:02:00               2
# ...                   ...            ...            ...             ...
# 3667             December             28       09:34:00               9
# 3668             December             28       09:35:00               9
# 3669             December             28       09:35:00               9
# 3670             December             28       09:41:00               9
# 3671             December             28       09:41:00               9
#
#       timestamp_minute  timestamp_second
# 0                   27                 0
# 1                   30                 0
# 2                    2                 0
# 3                    2                 0
# 4                    2                 0
# ...                ...               ...
# 3667                34                 0
# 3668                35                 0
# 3669                35                 0
# 3670                41                 0
# 3671                41                 0
#
# [3672 rows x 15 columns]

# %%
## creating 'day - amount' connection
group_day_amount = df['amount'].groupby(df['timestamp_year_month_day'])

# %%
group_day_amount.size()
# Out:
# timestamp_year_month_day
# 2018-12-02     334
# 2018-12-03     246
# 2018-12-19     125
# 2018-12-20    1045
# 2018-12-21    1406
# 2018-12-22     201
# 2018-12-27     140
# 2018-12-28     175
# Name: amount, dtype: int64

# %%
group_day_amount

# %%
## 일별 총 손익량
group_day_amount.sum()
# Out:
# timestamp_year_month_day
# 2018-12-02    -170441
# 2018-12-03     175400
# 2018-12-19      48014
# 2018-12-20   -6385830
# 2018-12-21    6321246
# 2018-12-22    -179293
# 2018-12-27     -46316
# 2018-12-28    -446386
# Name: amount, dtype: int64

# %%
## creating 'day - earning amount' connection
df2 = df.copy()
df2 =df2[df2['amount'] > 0]
group_day_amount_positive = df2['amount'].groupby(df2['timestamp_year_month_day'])

# %%
# 일별 수익 transaction 수
group_day_amount_positive.size()
# Out:
# timestamp_year_month_day
# 2018-12-02    211
# 2018-12-03    162
# 2018-12-19     61
# 2018-12-20    600
# 2018-12-21    721
# 2018-12-22    135
# 2018-12-27     57
# 2018-12-28    134
# Name: amount, dtype: int64

# %%
# 일별 수익량
group_day_amount_positive.sum()
# Out:
# timestamp_year_month_day
# 2018-12-02    190655671
# 2018-12-03    181207581
# 2018-12-19     59819114
# 2018-12-20    511010007
# 2018-12-21    623223575
# 2018-12-22    108705314
# 2018-12-27     55045007
# 2018-12-28    119682998
# Name: amount, dtype: int64

# %%
## creating 'day - loss amount' connection
df3 = df.copy()
df3 = df3[df3['amount'] < 0]
group_day_amount_negative = df3['amount'].groupby(df3['timestamp_year_month_day'])

# %%
# 일별 손해 transaction 수
group_day_amount_negative.size()
# Out:
# timestamp_year_month_day
# 2018-12-02    123
# 2018-12-03     83
# 2018-12-19     64
# 2018-12-20    444
# 2018-12-21    685
# 2018-12-22     66
# 2018-12-27     83
# 2018-12-28     41
# Name: amount, dtype: int64

# %%
# 일별 손해량
group_day_amount_negative.sum()
# Out:
# timestamp_year_month_day
# 2018-12-02   -190826112
# 2018-12-03   -181032181
# 2018-12-19    -59771100
# 2018-12-20   -517395837
# 2018-12-21   -616902329
# 2018-12-22   -108884607
# 2018-12-27    -55091323
# 2018-12-28   -120129384
# Name: amount, dtype: int64

# %%
# 일별 절대값 총합
absolute_negative_sum=group_day_amount_negative.sum()
absolute_negative_sum = absolute_negative_sum * (-1)
absolute_total_amout=absolute_negative_sum+group_day_amount_positive.sum()
absolute_total_amout
# Out:
# timestamp_year_month_day
# 2018-12-02     381481783
# 2018-12-03     362239762
# 2018-12-19     119590214
# 2018-12-20    1028405844
# 2018-12-21    1240125904
# 2018-12-22     217589921
# 2018-12-27     110136330
# 2018-12-28     239812382
# Name: amount, dtype: int64

# %%
## 일별 계산 table 생성
dfs = [group_day_amount.size(), group_day_amount.sum(), group_day_amount_positive.size(), group_day_amount_positive.sum(), group_day_amount_negative.size(), group_day_amount_negative.sum(), absolute_total_amout, absolute_negative_sum]
dfs
# Out:
# [timestamp_year_month_day
#  2018-12-02     334
#  2018-12-03     246
#  2018-12-19     125
#  2018-12-20    1045
#  2018-12-21    1406
#  2018-12-22     201
#  2018-12-27     140
#  2018-12-28     175
#  Name: amount, dtype: int64,
#  timestamp_year_month_day
#  2018-12-02    -170441
#  2018-12-03     175400
#  2018-12-19      48014
#  2018-12-20   -6385830
#  2018-12-21    6321246
#  2018-12-22    -179293
#  2018-12-27     -46316
#  2018-12-28    -446386
#  Name: amount, dtype: int64,
#  timestamp_year_month_day
#  2018-12-02    211
#  2018-12-03    162
#  2018-12-19     61
#  2018-12-20    600
#  2018-12-21    721
#  2018-12-22    135
#  2018-12-27     57
#  2018-12-28    134
#  Name: amount, dtype: int64,
#  timestamp_year_month_day
#  2018-12-02    190655671
#  2018-12-03    181207581
#  2018-12-19     59819114
#  2018-12-20    511010007
#  2018-12-21    623223575
#  2018-12-22    108705314
#  2018-12-27     55045007
#  2018-12-28    119682998
#  Name: amount, dtype: int64,
#  timestamp_year_month_day
#  2018-12-02    123
#  2018-12-03     83
#  2018-12-19     64
#  2018-12-20    444
#  2018-12-21    685
#  2018-12-22     66
#  2018-12-27     83
#  2018-12-28     41
#  Name: amount, dtype: int64,
#  timestamp_year_month_day
#  2018-12-02   -190826112
#  2018-12-03   -181032181
#  2018-12-19    -59771100
#  2018-12-20   -517395837
#  2018-12-21   -616902329
#  2018-12-22   -108884607
#  2018-12-27    -55091323
#  2018-12-28   -120129384
#  Name: amount, dtype: int64,
#  timestamp_year_month_day
#  2018-12-02     381481783
#  2018-12-03     362239762
#  2018-12-19     119590214
#  2018-12-20    1028405844
#  2018-12-21    1240125904
#  2018-12-22     217589921
#  2018-12-27     110136330
#  2018-12-28     239812382
#  Name: amount, dtype: int64,
#  timestamp_year_month_day
#  2018-12-02    190826112
#  2018-12-03    181032181
#  2018-12-19     59771100
#  2018-12-20    517395837
#  2018-12-21    616902329
#  2018-12-22    108884607
#  2018-12-27     55091323
#  2018-12-28    120129384
#  Name: amount, dtype: int64]

# %%
day_df_final = reduce(lambda left,right: pd.merge(left,right,on='timestamp_year_month_day'), dfs)
day_df_final.columns = [ "daily transaction", "daily income", "daily Yield transaction", "daily Yield", "daily loss transaction", "daily loss", "daily absolute amount", "daily absolute negative amount"]
day_df_final
# Out:
#                           daily transaction  daily income  \
# timestamp_year_month_day
# 2018-12-02                              334       -170441
# 2018-12-03                              246        175400
# 2018-12-19                              125         48014
# 2018-12-20                             1045      -6385830
# 2018-12-21                             1406       6321246
# 2018-12-22                              201       -179293
# 2018-12-27                              140        -46316
# 2018-12-28                              175       -446386
#
#                           daily Yield transaction  daily Yield  \
# timestamp_year_month_day
# 2018-12-02                                    211    190655671
# 2018-12-03                                    162    181207581
# 2018-12-19                                     61     59819114
# 2018-12-20                                    600    511010007
# 2018-12-21                                    721    623223575
# 2018-12-22                                    135    108705314
# 2018-12-27                                     57     55045007
# 2018-12-28                                    134    119682998
#
#                           daily loss transaction  daily loss  \
# timestamp_year_month_day
# 2018-12-02                                   123  -190826112
# 2018-12-03                                    83  -181032181
# 2018-12-19                                    64   -59771100
# 2018-12-20                                   444  -517395837
# 2018-12-21                                   685  -616902329
# 2018-12-22                                    66  -108884607
# 2018-12-27                                    83   -55091323
# 2018-12-28                                    41  -120129384
#
#                           daily absolute amount  \
# timestamp_year_month_day
# 2018-12-02                            381481783
# 2018-12-03                            362239762
# 2018-12-19                            119590214
# 2018-12-20                           1028405844
# 2018-12-21                           1240125904
# 2018-12-22                            217589921
# 2018-12-27                            110136330
# 2018-12-28                            239812382
#
#                           daily absolute negative amount
# timestamp_year_month_day
# 2018-12-02                                     190826112
# 2018-12-03                                     181032181
# 2018-12-19                                      59771100
# 2018-12-20                                     517395837
# 2018-12-21                                     616902329
# 2018-12-22                                     108884607
# 2018-12-27                                      55091323
# 2018-12-28                                     120129384

# %%
print(day_df_final.asfreq('D'))
# Out:
#                           daily transaction  daily income  \
# timestamp_year_month_day
# 2018-12-02                            334.0     -170441.0
# 2018-12-03                            246.0      175400.0
# 2018-12-04                              NaN           NaN
# 2018-12-05                              NaN           NaN
# 2018-12-06                              NaN           NaN
# 2018-12-07                              NaN           NaN
# 2018-12-08                              NaN           NaN
# 2018-12-09                              NaN           NaN
# 2018-12-10                              NaN           NaN
# 2018-12-11                              NaN           NaN
# 2018-12-12                              NaN           NaN
# 2018-12-13                              NaN           NaN
# 2018-12-14                              NaN           NaN
# 2018-12-15                              NaN           NaN
# 2018-12-16                              NaN           NaN
# 2018-12-17                              NaN           NaN
# 2018-12-18                              NaN           NaN
# 2018-12-19                            125.0       48014.0
# 2018-12-20                           1045.0    -6385830.0
# 2018-12-21                           1406.0     6321246.0
# 2018-12-22                            201.0     -179293.0
# 2018-12-23                              NaN           NaN
# 2018-12-24                              NaN           NaN
# 2018-12-25                              NaN           NaN
# 2018-12-26                              NaN           NaN
# 2018-12-27                            140.0      -46316.0
# 2018-12-28                            175.0     -446386.0
#
#                           daily Yield transaction  daily Yield  \
# timestamp_year_month_day
# 2018-12-02                                  211.0  190655671.0
# 2018-12-03                                  162.0  181207581.0
# 2018-12-04                                    NaN          NaN
# 2018-12-05                                    NaN          NaN
# 2018-12-06                                    NaN          NaN
# 2018-12-07                                    NaN          NaN
# 2018-12-08                                    NaN          NaN
# 2018-12-09                                    NaN          NaN
# 2018-12-10                                    NaN          NaN
# 2018-12-11                                    NaN          NaN
# 2018-12-12                                    NaN          NaN
# 2018-12-13                                    NaN          NaN
# 2018-12-14                                    NaN          NaN
# 2018-12-15                                    NaN          NaN
# 2018-12-16                                    NaN          NaN
# 2018-12-17                                    NaN          NaN
# 2018-12-18                                    NaN          NaN
# 2018-12-19                                   61.0   59819114.0
# 2018-12-20                                  600.0  511010007.0
# 2018-12-21                                  721.0  623223575.0
# 2018-12-22                                  135.0  108705314.0
# 2018-12-23                                    NaN          NaN
# 2018-12-24                                    NaN          NaN
# 2018-12-25                                    NaN          NaN
# 2018-12-26                                    NaN          NaN
# 2018-12-27                                   57.0   55045007.0
# 2018-12-28                                  134.0  119682998.0
#
#                           daily loss transaction   daily loss  \
# timestamp_year_month_day
# 2018-12-02                                 123.0 -190826112.0
# 2018-12-03                                  83.0 -181032181.0
# 2018-12-04                                   NaN          NaN
# 2018-12-05                                   NaN          NaN
# 2018-12-06                                   NaN          NaN
# 2018-12-07                                   NaN          NaN
# 2018-12-08                                   NaN          NaN
# 2018-12-09                                   NaN          NaN
# 2018-12-10                                   NaN          NaN
# 2018-12-11                                   NaN          NaN
# 2018-12-12                                   NaN          NaN
# 2018-12-13                                   NaN          NaN
# 2018-12-14                                   NaN          NaN
# 2018-12-15                                   NaN          NaN
# 2018-12-16                                   NaN          NaN
# 2018-12-17                                   NaN          NaN
# 2018-12-18                                   NaN          NaN
# 2018-12-19                                  64.0  -59771100.0
# 2018-12-20                                 444.0 -517395837.0
# 2018-12-21                                 685.0 -616902329.0
# 2018-12-22                                  66.0 -108884607.0
# 2018-12-23                                   NaN          NaN
# 2018-12-24                                   NaN          NaN
# 2018-12-25                                   NaN          NaN
# 2018-12-26                                   NaN          NaN
# 2018-12-27                                  83.0  -55091323.0
# 2018-12-28                                  41.0 -120129384.0
#
#                           daily absolute amount  \
# timestamp_year_month_day
# 2018-12-02                         3.814818e+08
# 2018-12-03                         3.622398e+08
# 2018-12-04                                  NaN
# 2018-12-05                                  NaN
# 2018-12-06                                  NaN
# 2018-12-07                                  NaN
# 2018-12-08                                  NaN
# 2018-12-09                                  NaN
# 2018-12-10                                  NaN
# 2018-12-11                                  NaN
# 2018-12-12                                  NaN
# 2018-12-13                                  NaN
# 2018-12-14                                  NaN
# 2018-12-15                                  NaN
# 2018-12-16                                  NaN
# 2018-12-17                                  NaN
# 2018-12-18                                  NaN
# 2018-12-19                         1.195902e+08
# 2018-12-20                         1.028406e+09
# 2018-12-21                         1.240126e+09
# 2018-12-22                         2.175899e+08
# 2018-12-23                                  NaN
# 2018-12-24                                  NaN
# 2018-12-25                                  NaN
# 2018-12-26                                  NaN
# 2018-12-27                         1.101363e+08
# 2018-12-28                         2.398124e+08
#
#                           daily absolute negative amount
# timestamp_year_month_day
# 2018-12-02                                   190826112.0
# 2018-12-03                                   181032181.0
# 2018-12-04                                           NaN
# 2018-12-05                                           NaN
# 2018-12-06                                           NaN
# 2018-12-07                                           NaN
# 2018-12-08                                           NaN
# 2018-12-09                                           NaN
# 2018-12-10                                           NaN
# 2018-12-11                                           NaN
# 2018-12-12                                           NaN
# 2018-12-13                                           NaN
# 2018-12-14                                           NaN
# 2018-12-15                                           NaN
# 2018-12-16                                           NaN
# 2018-12-17                                           NaN
# 2018-12-18                                           NaN
# 2018-12-19                                    59771100.0
# 2018-12-20                                   517395837.0
# 2018-12-21                                   616902329.0
# 2018-12-22                                   108884607.0
# 2018-12-23                                           NaN
# 2018-12-24                                           NaN
# 2018-12-25                                           NaN
# 2018-12-26                                           NaN
# 2018-12-27                                    55091323.0
# 2018-12-28                                   120129384.0

# %%
day_df_final.to_csv("/Users/hamin/bithumb_bot_data/upbit-2018-12-daily_result_table.csv", header=True, index=True, encoding = 'utf-8')

# %%
# 뒤집기.
day_df_final[::-1].to_csv("/Users/hamin/bithumb_bot_data/upbit-2018-12-daily_result_table.csv", header=True, index=True, encoding = 'utf-8')

# %%
day_df_final
# Out:
#                           daily transaction  daily income  \
# timestamp_year_month_day
# 2018-01-19                               40       1052348
# 2018-01-20                              153           426
# 2018-01-21                              154         -1741
# 2018-01-22                               69        -14922
# 2018-01-23                               96           899
# 2018-01-24                               86         -1680
# 2018-01-25                              217         11247
# 2018-01-31                                4           -86
#
#                           daily Yield transaction  daily Yield  \
# timestamp_year_month_day
# 2018-01-19                                     21      1334332
# 2018-01-20                                     76      1239191
# 2018-01-21                                     76      1201705
# 2018-01-22                                     34       480676
# 2018-01-23                                     48       633072
# 2018-01-24                                     42       565300
# 2018-01-25                                    109      1442316
# 2018-01-31                                      2        22176
#
#                           daily loss transaction  daily loss  \
# timestamp_year_month_day
# 2018-01-19                                    19     -281984
# 2018-01-20                                    77    -1238765
# 2018-01-21                                    78    -1203446
# 2018-01-22                                    35     -495598
# 2018-01-23                                    48     -632173
# 2018-01-24                                    44     -566980
# 2018-01-25                                   108    -1431069
# 2018-01-31                                     2      -22262
#
#                           daily absolute amount  \
# timestamp_year_month_day
# 2018-01-19                            1616316.0
# 2018-01-20                            2477956.0
# 2018-01-21                            2405151.0
# 2018-01-22                             976274.0
# 2018-01-23                            1265245.0
# 2018-01-24                            1132280.0
# 2018-01-25                            2873385.0
# 2018-01-31                              44438.0
#
#                           daily absolute negative amount
# timestamp_year_month_day
# 2018-01-19                                        281984
# 2018-01-20                                       1238765
# 2018-01-21                                       1203446
# 2018-01-22                                        495598
# 2018-01-23                                        632173
# 2018-01-24                                        566980
# 2018-01-25                                       1431069
# 2018-01-31                                         22262
