# %%
import pandas as pd
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, savefig
import time
import csv
import sys
import plotly.express as px

# %%
df = pd.read_csv("/Users/hamin/bithumb_bot_data/dailyVolume/Bithumb_BTC_Volume.csv")

# %%
df.dtypes
# Out:
# timestamp      object
# percentage    float64
# dtype: object

# %%
## converting timestamp column type 'object' to 'datetime'
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d', errors='raise')
df.dtypes
# Out:
# timestamp     datetime64[ns]
# percentage           float64
# dtype: object

# %%
# 뒤집기.
df2 = df[::-1]

# %%
df2
# Out:
#      timestamp  percentage
# 179 2018-01-19    0.000768
# 178 2018-01-20    0.000531
# 177 2018-01-21    0.001112
# 176 2018-01-22    0.000445
# 175 2018-01-23    0.000576
# ..         ...         ...
# 4   2018-07-13   10.046233
# 3   2018-07-14   10.573661
# 2   2018-07-15   14.321249
# 1   2018-07-16    6.520084
# 0   2018-07-17    0.007566
#
# [180 rows x 2 columns]

# %%
# 한글 폰트, 그래픽 크기 설정
plt.rcParams["font.family"] = 'DejaVu Sans'
plt.rcParams["font.size"] = 16
plt.rcParams["figure.figsize"] = (20, 10)

# %%
df2['percentage'].plot(color = '#ff0000')
plt.grid()
plt.legend()
plt.title("Bithumb-BTC transaction volume percentage")
plt.xlabel("Date")
plt.ylabel("percentage")
plt.show()

# %%
df2.head()
# Out:
#      timestamp  percentage
# 179 2018-01-19    0.000768
# 178 2018-01-20    0.000531
# 177 2018-01-21    0.001112
# 176 2018-01-22    0.000445
# 175 2018-01-23    0.000576

# %%
df3 = pd.read_csv("/Users/hamin/bithumb_bot_data/dailyVolume/Bithumb_BTC_Volume.csv", index_col='timestamp', parse_dates=True)

# %%
df3.head()
# Out:
#             percentage
# timestamp
# 2018-07-17    0.007566
# 2018-07-16    6.520084
# 2018-07-15   14.321249
# 2018-07-14   10.573661
# 2018-07-13   10.046233

# %%
df3['percentage'].plot(color = '#ff0000')
plt.grid()
plt.legend()
plt.title("Bithumb-BTC transaction volume percentage")
plt.xlabel("Date")
plt.ylabel("percentage")
plt.savefig('/Users/hamin/ITE3035_Python/Data_Science/graph/Bithumb-BTC-Vol_percentage.png', dpi=300)
plt.show()

# %%
# df3['percentage'].plot(xlim=['2018-01-01', '2018-02-28'], ylim=([-0.01,0.01]))
