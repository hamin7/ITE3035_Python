# %%
import pandas as pd
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, savefig

# 과학적 표기법(Scientific notation)을 사용하지 않는 경우
pd.options.display.float_format = '{:.4f}'.format

# %%
df = pd.read_csv("/Users/hamin/bithumb_bot_data/include/2018-new/2018-07-btc-krw-3.csv") # csv load

# %%
df.dtypes # identifying column type
# Out:
# timestamp     object
# quantity     float64
# price          int64
# fee            int64
# amount         int64
# side           int64
# dtype: object

# %%
df.dtypes # identifying column type
# Out:
# timestamp     object
# quantity     float64
# price          int64
# fee            int64
# amount         int64
# side           int64
# dtype: object

# %%
## converting timestamp column type 'object' to 'datetime'
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d %H:%M:%S', errors='raise')
df.dtypes
# Out:
# timestamp    datetime64[ns]
# quantity            float64
# price                 int64
# fee                   int64
# amount                int64
# side                  int64
# dtype: object

# %%
df
# Out:
#                timestamp  quantity    price  fee    amount  side
# 0    2018-07-04 12:37:00    0.9939  7151000    0  -7107379     0
# 1    2018-07-04 12:37:00    0.6190  7147000    0  -4423993     0
# 2    2018-07-04 12:59:00    1.6129  7144000    0  11522558     1
# 3    2018-07-04 13:17:00    0.5090  7149000    0  -3638841     0
# 4    2018-07-04 13:23:00    0.3929  7150000    0  -2809235     0
# ...                  ...       ...      ...  ...       ...   ...
# 7788 2018-07-16 23:59:00    0.0142  7384000    0    104853     1
# 7789 2018-07-16 23:59:00    0.1505  7384000    0   1111292     1
# 7790 2018-07-17 00:00:00    0.3153  7385000    0   2328491     1
# 7791 2018-07-17 00:00:00    0.0139  7385000    0   -102652     0
# 7792 2018-07-17 00:00:00    0.0139  7387000    0    102679     1
#
# [7793 rows x 6 columns]

# %%
# quantity에 부호 붙이기
for i, row in df.iterrows(): 
    if row["side"]==0:
        row["quantity"]=-row["quantity"]
    df.at[i,'sign_quantity'] = row["quantity"]

# %%
df.head(8)
# Out:
#             timestamp  quantity    price  fee    amount  side  sign_quantity
# 0 2018-07-04 12:37:00    0.9939  7151000    0  -7107379     0        -0.9939
# 1 2018-07-04 12:37:00    0.6190  7147000    0  -4423993     0        -0.6190
# 2 2018-07-04 12:59:00    1.6129  7144000    0  11522558     1         1.6129
# 3 2018-07-04 13:17:00    0.5090  7149000    0  -3638841     0        -0.5090
# 4 2018-07-04 13:23:00    0.3929  7150000    0  -2809235     0        -0.3929
# 5 2018-07-04 13:23:00    0.0001  7150000    0      -715     0        -0.0001
# 6 2018-07-04 13:25:00    0.2780  7147000    0  -1986866     0        -0.2780
# 7 2018-07-04 13:26:00    0.2550  7148000    0  -1822740     0        -0.2550

# %%
sign_quantity_cumsum=df["sign_quantity"].cumsum()
sign_quantity_cumsum
# Out:
# 0      -0.9939
# 1      -1.6129
# 2       0.0000
# 3      -0.5090
# 4      -0.9019
#          ...
# 7788   -0.4659
# 7789   -0.3154
# 7790   -0.0001
# 7791   -0.0140
# 7792   -0.0001
# Name: sign_quantity, Length: 7793, dtype: float64

# %%
amount_cumsum=df["amount"].cumsum()
amount_cumsum
# Out:
# 0       -7107379
# 1      -11531372
# 2          -8814
# 3       -3647655
# 4       -6456890
#           ...
# 7788    -3408724
# 7789    -2297432
# 7790       31059
# 7791      -71593
# 7792       31086
# Name: amount, Length: 7793, dtype: int64

# %%
sign_quantity_cumsum = sign_quantity_cumsum.astype('float16')

# %%
cumsum_df = pd.concat([df,sign_quantity_cumsum,amount_cumsum],axis=1)

# %%
cumsum_df
# Out:
#                timestamp  quantity    price  fee    amount  side  \
# 0    2018-07-04 12:37:00    0.9939  7151000    0  -7107379     0
# 1    2018-07-04 12:37:00    0.6190  7147000    0  -4423993     0
# 2    2018-07-04 12:59:00    1.6129  7144000    0  11522558     1
# 3    2018-07-04 13:17:00    0.5090  7149000    0  -3638841     0
# 4    2018-07-04 13:23:00    0.3929  7150000    0  -2809235     0
# ...                  ...       ...      ...  ...       ...   ...
# 7788 2018-07-16 23:59:00    0.0142  7384000    0    104853     1
# 7789 2018-07-16 23:59:00    0.1505  7384000    0   1111292     1
# 7790 2018-07-17 00:00:00    0.3153  7385000    0   2328491     1
# 7791 2018-07-17 00:00:00    0.0139  7385000    0   -102652     0
# 7792 2018-07-17 00:00:00    0.0139  7387000    0    102679     1
#
#       sign_quantity  sign_quantity    amount
# 0           -0.9939        -0.9941  -7107379
# 1           -0.6190        -1.6133 -11531372
# 2            1.6129         0.0000     -8814
# 3           -0.5090        -0.5088  -3647655
# 4           -0.3929        -0.9019  -6456890
# ...             ...            ...       ...
# 7788         0.0142        -0.4658  -3408724
# 7789         0.1505        -0.3154  -2297432
# 7790         0.3153        -0.0001     31059
# 7791        -0.0139        -0.0140    -71593
# 7792         0.0139        -0.0001     31086
#
# [7793 rows x 9 columns]

# %%
cumsum_df.columns = ['timestamp', 'quantity', 'price', 'fee', 'amount', 'side', 'sign_quantity', 'sign_quantity_cumsum(coin)', 'amount_cumsum']
cumsum_df
# Out:
#                timestamp  quantity    price  fee    amount  side  \
# 0    2018-07-04 12:37:00    0.9939  7151000    0  -7107379     0
# 1    2018-07-04 12:37:00    0.6190  7147000    0  -4423993     0
# 2    2018-07-04 12:59:00    1.6129  7144000    0  11522558     1
# 3    2018-07-04 13:17:00    0.5090  7149000    0  -3638841     0
# 4    2018-07-04 13:23:00    0.3929  7150000    0  -2809235     0
# ...                  ...       ...      ...  ...       ...   ...
# 7788 2018-07-16 23:59:00    0.0142  7384000    0    104853     1
# 7789 2018-07-16 23:59:00    0.1505  7384000    0   1111292     1
# 7790 2018-07-17 00:00:00    0.3153  7385000    0   2328491     1
# 7791 2018-07-17 00:00:00    0.0139  7385000    0   -102652     0
# 7792 2018-07-17 00:00:00    0.0139  7387000    0    102679     1
#
#       sign_quantity  sign_quantity_cumsum(coin)  amount_cumsum
# 0           -0.9939                     -0.9941       -7107379
# 1           -0.6190                     -1.6133      -11531372
# 2            1.6129                      0.0000          -8814
# 3           -0.5090                     -0.5088       -3647655
# 4           -0.3929                     -0.9019       -6456890
# ...             ...                         ...            ...
# 7788         0.0142                     -0.4658       -3408724
# 7789         0.1505                     -0.3154       -2297432
# 7790         0.3153                     -0.0001          31059
# 7791        -0.0139                     -0.0140         -71593
# 7792         0.0139                     -0.0001          31086
#
# [7793 rows x 9 columns]

# %%
cumsum_df_zero_point=cumsum_df[ (cumsum_df['sign_quantity_cumsum(coin)'] < 0.00001) & (cumsum_df['sign_quantity_cumsum(coin)'] > -0.00001)]

# %%
compare=cumsum_df_zero_point['amount_cumsum']
compare=compare.shift(1)[:]
compare
# Out:
# 2               nan
# 26       -8814.0000
# 31      -17234.0000
# 34      -17660.0000
# 40      -16973.0000
#            ...
# 6388   -290927.0000
# 6401   -291205.0000
# 6423   -313694.0000
# 6425   -282593.0000
# 6748   -282627.0000
# Name: amount_cumsum, Length: 90, dtype: float64

# %%
cumsum_df_zero_point = pd.concat([cumsum_df_zero_point,compare],axis=1)
cumsum_df_zero_point=cumsum_df_zero_point.fillna(0)
cumsum_df_zero_point
# Out:
#                timestamp  quantity    price  fee    amount  side  \
# 2    2018-07-04 12:59:00    1.6129  7144000    0  11522558     1
# 26   2018-07-04 13:36:00    0.2332  7143000    0   1665748     1
# 31   2018-07-04 14:25:00    0.0130  7140000    0     92820     1
# 34   2018-07-04 14:38:00    0.0388  7166000    0    278041     1
# 40   2018-07-04 14:56:00    0.1239  7165000    0    887744     1
# ...                  ...       ...      ...  ...       ...   ...
# 6388 2018-07-14 23:23:00    0.1206  7093000    0    855416     1
# 6401 2018-07-15 00:04:00    2.9410  7091000    0  20854631     1
# 6423 2018-07-15 01:02:00    1.4979  7111000    0  10651567     1
# 6425 2018-07-15 01:05:00    0.0170  7112000    0    120904     1
# 6748 2018-07-15 11:30:00    0.1547  7118000    0   1101155     1
#
#       sign_quantity  sign_quantity_cumsum(coin)  amount_cumsum  amount_cumsum
# 2            1.6129                      0.0000          -8814         0.0000
# 26           0.2332                     -0.0000         -17234     -8814.0000
# 31           0.0130                     -0.0000         -17660    -17234.0000
# 34           0.0388                     -0.0000         -16973    -17660.0000
# 40           0.1239                     -0.0000         -18168    -16973.0000
# ...             ...                         ...            ...            ...
# 6388         0.1206                     -0.0000        -291205   -290927.0000
# 6401         2.9410                     -0.0000        -313694   -291205.0000
# 6423         1.4979                     -0.0000        -282593   -313694.0000
# 6425         0.0170                     -0.0000        -282627   -282593.0000
# 6748         0.1547                     -0.0000        -158543   -282627.0000
#
# [90 rows x 10 columns]

# %%
cumsum_df_zero_point.columns = ['timestamp', 'quantity', 'price', 'fee', 'amount', 'side', 'sign_quantity', 'sign_quantity_cumsum(coin)', 'amount_cumsum', 'compare']
cumsum_df_zero_point
# Out:
#                timestamp  quantity    price  fee    amount  side  \
# 2    2018-07-04 12:59:00    1.6129  7144000    0  11522558     1
# 26   2018-07-04 13:36:00    0.2332  7143000    0   1665748     1
# 31   2018-07-04 14:25:00    0.0130  7140000    0     92820     1
# 34   2018-07-04 14:38:00    0.0388  7166000    0    278041     1
# 40   2018-07-04 14:56:00    0.1239  7165000    0    887744     1
# ...                  ...       ...      ...  ...       ...   ...
# 6388 2018-07-14 23:23:00    0.1206  7093000    0    855416     1
# 6401 2018-07-15 00:04:00    2.9410  7091000    0  20854631     1
# 6423 2018-07-15 01:02:00    1.4979  7111000    0  10651567     1
# 6425 2018-07-15 01:05:00    0.0170  7112000    0    120904     1
# 6748 2018-07-15 11:30:00    0.1547  7118000    0   1101155     1
#
#       sign_quantity  sign_quantity_cumsum(coin)  amount_cumsum      compare
# 2            1.6129                      0.0000          -8814       0.0000
# 26           0.2332                     -0.0000         -17234   -8814.0000
# 31           0.0130                     -0.0000         -17660  -17234.0000
# 34           0.0388                     -0.0000         -16973  -17660.0000
# 40           0.1239                     -0.0000         -18168  -16973.0000
# ...             ...                         ...            ...          ...
# 6388         0.1206                     -0.0000        -291205 -290927.0000
# 6401         2.9410                     -0.0000        -313694 -291205.0000
# 6423         1.4979                     -0.0000        -282593 -313694.0000
# 6425         0.0170                     -0.0000        -282627 -282593.0000
# 6748         0.1547                     -0.0000        -158543 -282627.0000
#
# [90 rows x 10 columns]

# %%
cumsum_df_zero_point['point_amount_cumsum'] = cumsum_df_zero_point['amount_cumsum'] - cumsum_df_zero_point['compare']

# %%
cumsum_df_zero_point=cumsum_df_zero_point.fillna(0)
cumsum_df_zero_point
# Out:
#                timestamp  quantity    price  fee    amount  side  \
# 2    2018-07-04 12:59:00    1.6129  7144000    0  11522558     1
# 26   2018-07-04 13:36:00    0.2332  7143000    0   1665748     1
# 31   2018-07-04 14:25:00    0.0130  7140000    0     92820     1
# 34   2018-07-04 14:38:00    0.0388  7166000    0    278041     1
# 40   2018-07-04 14:56:00    0.1239  7165000    0    887744     1
# ...                  ...       ...      ...  ...       ...   ...
# 6388 2018-07-14 23:23:00    0.1206  7093000    0    855416     1
# 6401 2018-07-15 00:04:00    2.9410  7091000    0  20854631     1
# 6423 2018-07-15 01:02:00    1.4979  7111000    0  10651567     1
# 6425 2018-07-15 01:05:00    0.0170  7112000    0    120904     1
# 6748 2018-07-15 11:30:00    0.1547  7118000    0   1101155     1
#
#       sign_quantity  sign_quantity_cumsum(coin)  amount_cumsum      compare  \
# 2            1.6129                      0.0000          -8814       0.0000
# 26           0.2332                     -0.0000         -17234   -8814.0000
# 31           0.0130                     -0.0000         -17660  -17234.0000
# 34           0.0388                     -0.0000         -16973  -17660.0000
# 40           0.1239                     -0.0000         -18168  -16973.0000
# ...             ...                         ...            ...          ...
# 6388         0.1206                     -0.0000        -291205 -290927.0000
# 6401         2.9410                     -0.0000        -313694 -291205.0000
# 6423         1.4979                     -0.0000        -282593 -313694.0000
# 6425         0.0170                     -0.0000        -282627 -282593.0000
# 6748         0.1547                     -0.0000        -158543 -282627.0000
#
#       point_amount_cumsum
# 2              -8814.0000
# 26             -8420.0000
# 31              -426.0000
# 34               687.0000
# 40             -1195.0000
# ...                   ...
# 6388            -278.0000
# 6401          -22489.0000
# 6423           31101.0000
# 6425             -34.0000
# 6748          124084.0000
#
# [90 rows x 11 columns]

# %%
profit_graph=cumsum_df_zero_point[['amount_cumsum']].plot(title='profit_graph')
profit_graph.set_xlabel('date')
profit_graph.set_ylabel('Profit_price(1 thousand krw)')
profit_graph.set_yticklabels(['$0$', '$0$','$2,000$','$4,000$','$6,000$','$8,000$','$10,000$', '$12,000$'])
profit_graph.set_xticklabels(['$0$', '$03/07$', '$03/13$', '$03/20$', '$03/26$'])
# Out:
# [Text(0, 0, '$0$'),
#  Text(0, 0, '$03/07$'),
#  Text(0, 0, '$03/13$'),
#  Text(0, 0, '$03/20$'),
#  Text(0, 0, '$03/26$')]

# %%
profit_point_graph_table=cumsum_df_zero_point[['timestamp', 'point_amount_cumsum']]
profit_point_graph_table.to_csv("/Users/hamin/ITE3035_Python/Data_Science/endingPrice/profit_point.csv", header=True, index=True, encoding = 'utf-8')
profit_point_graph_table
# Out:
#                timestamp  point_amount_cumsum
# 2    2018-07-04 12:59:00           -8814.0000
# 26   2018-07-04 13:36:00           -8420.0000
# 31   2018-07-04 14:25:00            -426.0000
# 34   2018-07-04 14:38:00             687.0000
# 40   2018-07-04 14:56:00           -1195.0000
# ...                  ...                  ...
# 6388 2018-07-14 23:23:00            -278.0000
# 6401 2018-07-15 00:04:00          -22489.0000
# 6423 2018-07-15 01:02:00           31101.0000
# 6425 2018-07-15 01:05:00             -34.0000
# 6748 2018-07-15 11:30:00          124084.0000
#
# [90 rows x 2 columns]
