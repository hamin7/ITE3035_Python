# %%
import pandas as pd
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, savefig
import time
import csv
import sys
import plotly.express as px

# %%
df = pd.read_csv("/Users/hamin/bithumb_bot_data/endingPrice/BTC_KRW_EndingPrice.csv")

# %%
df.dtypes
# Out:
# timestamp       object
# endingPrice    float64
# dtype: object

# %%
## converting timestamp column type 'object' to 'datetime'
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d', errors='raise')
df.dtypes
# Out:
# timestamp      datetime64[ns]
# endingPrice           float64
# dtype: object

# %%
# 뒤집기.
df2 = df[::-1]

# %%
df2
# Out:
#      timestamp  endingPrice
# 193        NaT          NaN
# 192        NaT          NaN
# 191        NaT          NaN
# 190        NaT          NaN
# 189        NaT          NaN
# ..         ...          ...
# 4   2018-07-13    7075000.0
# 3   2018-07-14    7119000.0
# 2   2018-07-15    7192000.0
# 1   2018-07-16    7475000.0
# 0   2018-07-17    8031000.0
#
# [194 rows x 2 columns]

# %%
# 한글 폰트, 그래픽 크기 설정
plt.rcParams["font.family"] = 'DejaVu Sans'
plt.rcParams["font.size"] = 16
plt.rcParams["figure.figsize"] = (20, 10)

# %%
df2['endingPrice'].plot(color = '#ff0000')
plt.grid()
plt.legend()
plt.title("Bithumb-BTC daily ending price")
plt.xlabel("Date")
plt.ylabel("endingPrice")
plt.show()

# %%
df2.head()
# Out:
#     timestamp  endingPrice
# 193       NaT          NaN
# 192       NaT          NaN
# 191       NaT          NaN
# 190       NaT          NaN
# 189       NaT          NaN

# %%
df3 = pd.read_csv("/Users/hamin/bithumb_bot_data/endingPrice/BTC_KRW_EndingPrice.csv", index_col='timestamp', parse_dates=True)

# %%
df3.head()
# Out:
#             endingPrice
# timestamp
# 2018-07-17    8031000.0
# 2018-07-16    7475000.0
# 2018-07-15    7192000.0
# 2018-07-14    7119000.0
# 2018-07-13    7075000.0

# %%
df3['endingPrice'].plot(color = '#ff0000')
plt.grid()
plt.legend()
plt.title("Bithumb-BTC Ending Price (2018.02.14 ~ 2018.07.17)")
plt.xlabel("Date")
plt.ylabel("Ending Price (10,000,000KRW)")
plt.savefig('/Users/hamin/ITE3035_Python/Data_Science/graph/Bithumb-BTC-EndingPrice.png', dpi=300)
plt.show()

# %%
# df3['percentage'].plot(xlim=['2018-01-01', '2018-02-28'], ylim=([-0.01,0.01]))
